# %% [markdown]
# # Import Things

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv("C:\\Users\\acer\\WhiteIceAnalytics\\test.csv")

# %%
df['True_Adj_Sv%'] = df['True_Adj_Sv%'].fillna(0)
df['GSAA'] = df['GSAA'].fillna(0)

# %%
df['GP'] = df['GP'].astype(np.int64)
df['GS'] = df['GS'].astype(np.int64)
df['W'] = df['W'].astype(np.int64)
df['L'] = df['L'].astype(np.int64)
df['T'] = df['T'].astype(np.int64)
df['OT'] = df['OT'].astype(np.int64)
df['GA'] = df['GA'].astype(np.int64)
df['SO'] = df['SO'].astype(np.int64)
df['G'] = df['G'].astype(np.int64)
df['A'] = df['A'].astype(np.int64)
df['P'] = df['P'].astype(np.int64)
df['PIM'] = df['PIM'].astype(np.int64)
df['True_Adj_GAA'] = df['True_Adj_GAA'].round(2)
df['TOI'] = df['TOI'].round(2)
df['Actual GP'] = df['Actual GP'].round(2)
df['Prop GP'] = df['Prop GP'].round(2)
df['True_Adj_Sv%'] = df['True_Adj_Sv%'].round(3)
df['GSAA'] = df['GSAA'].round(2)

# %%
df
# Out:
#                  Player    Season Team S/C  GP  GS   W   L  T  OT  SA  Svs  \
# 0        Georges Vezina  19171918  MTL   L  21  21  12   9  0   0   0    0
# 1        Clint Benedict  19171918  SEN   L  22  22   9  13  0   0   0    0
# 2            Hap Holmes  19171918  TAN   L  16  16   9   7  0   0   0    0
# 3            Art Brooks  19171918  TAN   R   4   3   2   2  0   0   0    0
# 4          Bert Lindsay  19171918  MWN   R   4   4   1   3  0   0   0    0
# ...                 ...       ...  ...  ..  ..  ..  ..  .. ..  ..  ..  ...
# 4453     Louis Domingue  20202021  CGY   R   1   1   0   1  0   0  23   20
# 4454   Alexei Melnichuk  20202021  SJS   L   3   2   0   1  0   1  81   70
# 4455     Ivan Prosvetov  20202021  ARI   L   3   1   0   1  0   0  51   42
# 4456   Artyom Zagidulin  20202021  CGY   L   1   0   0   0  0   0  11    9
# 4457  Veini Vehvilainen  20202021  CBJ   L   1   0   0   0  0   0   4    3
#
#        GA    Sv%   GAA      TOI  SO  G  A  P  PIM  Actual GP  Prop GP 25+  \
# 0      84  0.000  3.93  1282.25   1  0  0  0    0      21.37     0.97   Y
# 1     114  0.000  5.11  1337.25   1  0  0  0    0      22.29     1.01   Y
# 2      76  0.000  4.73   965.00   0  0  0  0    0      16.08     0.73   Y
# 3      23  0.000  6.27   220.00   0  0  0  0    0       3.67     0.17   N
# 4      35  0.000  8.75   240.00   0  0  0  0    0       4.00     0.18   N
# ...   ...    ...   ...      ...  .. .. .. ..  ...        ...      ...  ..
# 4453    3  0.870  3.12    57.70   0  0  0  0    0       0.96     0.02   N
# 4454   11  0.864  5.05   130.58   0  0  0  0    0       2.18     0.04   N
# 4455    9  0.824  4.15   130.02   0  0  0  0    0       2.17     0.04   N
# 4456    2  0.818  4.25    28.22   0  0  0  0    0       0.47     0.01   N
# 4457    1  0.750  5.63    10.67   0  0  0  0    0       0.18     0.00   N
#
#       True_Adj_GAA  True_Adj_Sv%  GSAA
# 0             2.08         0.000  0.00
# 1             2.70         0.000  0.00
# 2             2.50         0.000  0.00
# 3             3.31         0.000  0.00
# 4             4.62         0.000  0.00
# ...            ...           ...   ...
# 4453          3.12         0.870 -0.88
# 4454          5.05         0.864 -3.54
# 4455          4.15         0.824 -4.30
# 4456          4.25         0.818 -0.99
# 4457          5.63         0.750 -0.63
#
# [4458 rows x 27 columns]

# %% [markdown]
# # Save As HTML

# %%
df.to_html("C:\\Users\\acer\\WhiteIceAnalytics\\index.html", index = False)
