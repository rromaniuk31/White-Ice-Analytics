# %% [markdown]
# # Import Things

# %%
import pandas as pd
import numpy as np
import random
import tensorflow as tf
import decimal
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
pd.set_option('display.max_columns', None)
random.seed(2021)
tf.random.set_seed(2021)

# %% [markdown]
# # Get Data

# %%
#Read CSV
df = pd.read_csv("C:\\Users\\acer\\WhiteIceAnalytics\\25plus_per.csv")

# %%
#Split Data At 1955-56 Season
pre56_df = df[df.SA == 0]
post56_df = df[df.SA != 0]
post56_df = post56_df.reset_index(drop = True)

# %% [markdown]
# # K=50 Fold Cross Validation

# %%
#Initialize Cross Validation
X = post56_df['GAA']
y = post56_df['Sv%']

k = 50
cv = KFold(n_splits = k, random_state = 0)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(

# %% [markdown]
# ## Create Folds

# %%
#Select Random Samples (49 0f size 45, 1 of size 44)
nums = pd.DataFrame(range(0, len(post56_df)), index = range(0, len(post56_df)), columns = ["Number"])

n1 = int(len(post56_df)/k)+1
n2 = int(len(post56_df)/k)

df_samps = [0]*50
for i in range(0, 49):
    df_samps[i] = nums['Number'].sample(n=n1, random_state=2021)
    nums = nums.drop(df_samps[i])
    
df_samps[49] = nums['Number'].sample(n=n2, random_state=2021)
nums = nums.drop(df_samps[49])

# %%
#Initialize 50 Folds
X_trains = [0]*50
y_trains = [0]*50

for i in range(0, len(df_samps)):
    X_trains[i] = pd.DataFrame(data=df_samps[i])
    X_trains[i]['GAA'] = ''
    
for i in range(0, len(df_samps)):
    y_trains[i] = pd.DataFrame(data=df_samps[i])
    y_trains[i]['Sv%'] = ''

# %%
#Input Data Into Folds
for j in range(0, len(X_trains)):
    for i in X_trains[j]['Number']:
        X_trains[j]['GAA'][i] = X[i] 
        
for j in range(0, len(y_trains)):
    for i in y_trains[j]['Number']:
        y_trains[j]['Sv%'][i] = y[i]
# Out:
# <ipython-input-7-729bb7e145f6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_trains[j]['GAA'][i] = X[i]
# <ipython-input-7-729bb7e145f6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_trains[j]['Sv%'][i] = y[i]

# %%
#Turn X_trains Into DataFrames
for i in range(0, len(X_trains)):
    X_trains[i] = pd.DataFrame(data = X_trains[i])
    
#Turn y_trains Into DataFrames
for i in range(0, len(y_trains)):
    y_trains[i] = pd.DataFrame(data = y_trains[i])

# %%
#Create 50 X Folds
X_fold0 = pd.concat([X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold1 = pd.concat([X_trains[0], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold2 = pd.concat([X_trains[0], X_trains[1], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold3 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold4 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold5 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold6 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold7 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold8 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold9 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold10 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold11 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold12 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold13 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold14 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold15 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold16 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold17 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold18 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold19 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold20 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold21 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold22 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold23 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold24 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold25 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold26 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold27 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold28 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold29 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold30 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold31 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold32 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold33 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold34 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold35 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold36 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold37 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold38 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold39 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold40 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold41 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold42 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold43 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold44 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[45], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold45 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[46], X_trains[47], X_trains[48], X_trains[49]])
X_fold46 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[47], X_trains[48], X_trains[49]])
X_fold47 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[48], X_trains[49]])
X_fold48 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[49]])
X_fold49 = pd.concat([X_trains[0], X_trains[1], X_trains[2], X_trains[3], X_trains[4], X_trains[5], X_trains[6], X_trains[7], X_trains[8], X_trains[9], X_trains[10], X_trains[11], X_trains[12], X_trains[13], X_trains[14], X_trains[15], X_trains[16], X_trains[17], X_trains[18], X_trains[19], X_trains[20], X_trains[21], X_trains[22], X_trains[23], X_trains[24], X_trains[25], X_trains[26], X_trains[27], X_trains[28], X_trains[29], X_trains[30], X_trains[31], X_trains[32], X_trains[33], X_trains[34], X_trains[35], X_trains[36], X_trains[37], X_trains[38], X_trains[39], X_trains[40], X_trains[41], X_trains[42], X_trains[43], X_trains[44], X_trains[45], X_trains[46], X_trains[47], X_trains[48]])


#Create 50 y Folds
y_fold0 = pd.concat([y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold1 = pd.concat([y_trains[0], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold2 = pd.concat([y_trains[0], y_trains[1], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold3 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold4 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold5 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold6 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold7 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold8 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold9 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold10 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold11 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold12 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold13 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold14 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold15 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold16 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold17 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold18 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold19 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold20 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold21 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold22 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold23 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold24 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold25 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold26 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold27 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold28 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold29 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold30 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold31 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold32 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold33 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold34 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold35 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold36 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold37 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold38 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold39 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold40 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold41 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold42 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold43 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold44 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[45], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold45 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[46], y_trains[47], y_trains[48], y_trains[49]])
y_fold46 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[47], y_trains[48], y_trains[49]])
y_fold47 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[48], y_trains[49]])
y_fold48 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[49]])
y_fold49 = pd.concat([y_trains[0], y_trains[1], y_trains[2], y_trains[3], y_trains[4], y_trains[5], y_trains[6], y_trains[7], y_trains[8], y_trains[9], y_trains[10], y_trains[11], y_trains[12], y_trains[13], y_trains[14], y_trains[15], y_trains[16], y_trains[17], y_trains[18], y_trains[19], y_trains[20], y_trains[21], y_trains[22], y_trains[23], y_trains[24], y_trains[25], y_trains[26], y_trains[27], y_trains[28], y_trains[29], y_trains[30], y_trains[31], y_trains[32], y_trains[33], y_trains[34], y_trains[35], y_trains[36], y_trains[37], y_trains[38], y_trains[39], y_trains[40], y_trains[41], y_trains[42], y_trains[43], y_trains[44], y_trains[45], y_trains[46], y_trains[47], y_trains[48]])

# %%
#Create Test X Folds
X_test_fold0 = X_trains[0]
X_test_fold1 = X_trains[1]
X_test_fold2 = X_trains[2]
X_test_fold3 = X_trains[3]
X_test_fold4 = X_trains[4]
X_test_fold5 = X_trains[5]
X_test_fold6 = X_trains[6]
X_test_fold7 = X_trains[7]
X_test_fold8 = X_trains[8]
X_test_fold9 = X_trains[9]
X_test_fold10 = X_trains[10]
X_test_fold11 = X_trains[11]
X_test_fold12 = X_trains[12]
X_test_fold13 = X_trains[13]
X_test_fold14 = X_trains[14]
X_test_fold15 = X_trains[15]
X_test_fold16 = X_trains[16]
X_test_fold17 = X_trains[17]
X_test_fold18 = X_trains[18]
X_test_fold19 = X_trains[19]
X_test_fold20 = X_trains[20]
X_test_fold21 = X_trains[21]
X_test_fold22 = X_trains[22]
X_test_fold23 = X_trains[23]
X_test_fold24 = X_trains[24]
X_test_fold25 = X_trains[25]
X_test_fold26 = X_trains[26]
X_test_fold27 = X_trains[27]
X_test_fold28 = X_trains[28]
X_test_fold29 = X_trains[29]
X_test_fold30 = X_trains[30]
X_test_fold31 = X_trains[31]
X_test_fold32 = X_trains[32]
X_test_fold33 = X_trains[33]
X_test_fold34 = X_trains[34]
X_test_fold35 = X_trains[35]
X_test_fold36 = X_trains[36]
X_test_fold37 = X_trains[37]
X_test_fold38 = X_trains[38]
X_test_fold39 = X_trains[39]
X_test_fold40 = X_trains[40]
X_test_fold41 = X_trains[41]
X_test_fold42 = X_trains[42]
X_test_fold43 = X_trains[43]
X_test_fold44 = X_trains[44]
X_test_fold45 = X_trains[45]
X_test_fold46 = X_trains[46]
X_test_fold47 = X_trains[47]
X_test_fold48 = X_trains[48]
X_test_fold49 = X_trains[49]


#Create Test y Folds
y_test_fold0 = y_trains[0]
y_test_fold1 = y_trains[1]
y_test_fold2 = y_trains[2]
y_test_fold3 = y_trains[3]
y_test_fold4 = y_trains[4]
y_test_fold5 = y_trains[5]
y_test_fold6 = y_trains[6]
y_test_fold7 = y_trains[7]
y_test_fold8 = y_trains[8]
y_test_fold9 = y_trains[9]
y_test_fold10 = y_trains[10]
y_test_fold11 = y_trains[11]
y_test_fold12 = y_trains[12]
y_test_fold13 = y_trains[13]
y_test_fold14 = y_trains[14]
y_test_fold15 = y_trains[15]
y_test_fold16 = y_trains[16]
y_test_fold17 = y_trains[17]
y_test_fold18 = y_trains[18]
y_test_fold19 = y_trains[19]
y_test_fold20 = y_trains[20]
y_test_fold21 = y_trains[21]
y_test_fold22 = y_trains[22]
y_test_fold23 = y_trains[23]
y_test_fold24 = y_trains[24]
y_test_fold25 = y_trains[25]
y_test_fold26 = y_trains[26]
y_test_fold27 = y_trains[27]
y_test_fold28 = y_trains[28]
y_test_fold29 = y_trains[29]
y_test_fold30 = y_trains[30]
y_test_fold31 = y_trains[31]
y_test_fold32 = y_trains[32]
y_test_fold33 = y_trains[33]
y_test_fold34 = y_trains[34]
y_test_fold35 = y_trains[35]
y_test_fold36 = y_trains[36]
y_test_fold37 = y_trains[37]
y_test_fold38 = y_trains[38]
y_test_fold39 = y_trains[39]
y_test_fold40 = y_trains[40]
y_test_fold41 = y_trains[41]
y_test_fold42 = y_trains[42]
y_test_fold43 = y_trains[43]
y_test_fold44 = y_trains[44]
y_test_fold45 = y_trains[45]
y_test_fold46 = y_trains[46]
y_test_fold47 = y_trains[47]
y_test_fold48 = y_trains[48]
y_test_fold49 = y_trains[49]

# %% [markdown]
# ## Linear Regression

# %%
lin_reg0 = LinearRegression()
lin_reg1 = LinearRegression()
lin_reg2 = LinearRegression()
lin_reg3 = LinearRegression()
lin_reg4 = LinearRegression()
lin_reg5 = LinearRegression()
lin_reg6 = LinearRegression()
lin_reg7 = LinearRegression()
lin_reg8 = LinearRegression()
lin_reg9 = LinearRegression()
lin_reg10 = LinearRegression()
lin_reg11 = LinearRegression()
lin_reg12 = LinearRegression()
lin_reg13 = LinearRegression()
lin_reg14 = LinearRegression()
lin_reg15 = LinearRegression()
lin_reg16 = LinearRegression()
lin_reg17 = LinearRegression()
lin_reg18 = LinearRegression()
lin_reg19 = LinearRegression()
lin_reg20 = LinearRegression()
lin_reg21 = LinearRegression()
lin_reg22 = LinearRegression()
lin_reg23 = LinearRegression()
lin_reg24 = LinearRegression()
lin_reg25 = LinearRegression()
lin_reg26 = LinearRegression()
lin_reg27 = LinearRegression()
lin_reg28 = LinearRegression()
lin_reg29 = LinearRegression()
lin_reg30 = LinearRegression()
lin_reg31 = LinearRegression()
lin_reg32 = LinearRegression()
lin_reg33 = LinearRegression()
lin_reg34 = LinearRegression()
lin_reg35 = LinearRegression()
lin_reg36 = LinearRegression()
lin_reg37 = LinearRegression()
lin_reg38 = LinearRegression()
lin_reg39 = LinearRegression()
lin_reg40 = LinearRegression()
lin_reg41 = LinearRegression()
lin_reg42 = LinearRegression()
lin_reg43 = LinearRegression()
lin_reg44 = LinearRegression()
lin_reg45 = LinearRegression()
lin_reg46 = LinearRegression()
lin_reg47 = LinearRegression()
lin_reg48 = LinearRegression()
lin_reg49 = LinearRegression()

# %%
lin_reg0.fit(X_fold0[['GAA']], y_fold0['Sv%'])
lin_reg1.fit(X_fold1[['GAA']], y_fold1['Sv%'])
lin_reg2.fit(X_fold2[['GAA']], y_fold2['Sv%'])
lin_reg3.fit(X_fold3[['GAA']], y_fold3['Sv%'])
lin_reg4.fit(X_fold4[['GAA']], y_fold4['Sv%'])
lin_reg5.fit(X_fold5[['GAA']], y_fold5['Sv%'])
lin_reg6.fit(X_fold6[['GAA']], y_fold6['Sv%'])
lin_reg7.fit(X_fold7[['GAA']], y_fold7['Sv%'])
lin_reg8.fit(X_fold8[['GAA']], y_fold8['Sv%'])
lin_reg9.fit(X_fold9[['GAA']], y_fold9['Sv%'])
lin_reg10.fit(X_fold10[['GAA']], y_fold10['Sv%'])
lin_reg11.fit(X_fold11[['GAA']], y_fold11['Sv%'])
lin_reg12.fit(X_fold12[['GAA']], y_fold12['Sv%'])
lin_reg13.fit(X_fold13[['GAA']], y_fold13['Sv%'])
lin_reg14.fit(X_fold14[['GAA']], y_fold14['Sv%'])
lin_reg15.fit(X_fold15[['GAA']], y_fold15['Sv%'])
lin_reg16.fit(X_fold16[['GAA']], y_fold16['Sv%'])
lin_reg17.fit(X_fold17[['GAA']], y_fold17['Sv%'])
lin_reg18.fit(X_fold18[['GAA']], y_fold18['Sv%'])
lin_reg19.fit(X_fold19[['GAA']], y_fold19['Sv%'])
lin_reg20.fit(X_fold20[['GAA']], y_fold20['Sv%'])
lin_reg21.fit(X_fold21[['GAA']], y_fold21['Sv%'])
lin_reg22.fit(X_fold22[['GAA']], y_fold22['Sv%'])
lin_reg23.fit(X_fold23[['GAA']], y_fold23['Sv%'])
lin_reg24.fit(X_fold24[['GAA']], y_fold24['Sv%'])
lin_reg25.fit(X_fold25[['GAA']], y_fold25['Sv%'])
lin_reg26.fit(X_fold26[['GAA']], y_fold26['Sv%'])
lin_reg27.fit(X_fold27[['GAA']], y_fold27['Sv%'])
lin_reg28.fit(X_fold28[['GAA']], y_fold28['Sv%'])
lin_reg29.fit(X_fold29[['GAA']], y_fold29['Sv%'])
lin_reg30.fit(X_fold30[['GAA']], y_fold30['Sv%'])
lin_reg31.fit(X_fold31[['GAA']], y_fold31['Sv%'])
lin_reg32.fit(X_fold32[['GAA']], y_fold32['Sv%'])
lin_reg33.fit(X_fold33[['GAA']], y_fold33['Sv%'])
lin_reg34.fit(X_fold34[['GAA']], y_fold34['Sv%'])
lin_reg35.fit(X_fold35[['GAA']], y_fold35['Sv%'])
lin_reg36.fit(X_fold36[['GAA']], y_fold36['Sv%'])
lin_reg37.fit(X_fold37[['GAA']], y_fold37['Sv%'])
lin_reg38.fit(X_fold38[['GAA']], y_fold38['Sv%'])
lin_reg39.fit(X_fold39[['GAA']], y_fold39['Sv%'])
lin_reg40.fit(X_fold40[['GAA']], y_fold40['Sv%'])
lin_reg41.fit(X_fold41[['GAA']], y_fold41['Sv%'])
lin_reg42.fit(X_fold42[['GAA']], y_fold42['Sv%'])
lin_reg43.fit(X_fold43[['GAA']], y_fold43['Sv%'])
lin_reg44.fit(X_fold44[['GAA']], y_fold44['Sv%'])
lin_reg45.fit(X_fold45[['GAA']], y_fold45['Sv%'])
lin_reg46.fit(X_fold46[['GAA']], y_fold46['Sv%'])
lin_reg47.fit(X_fold47[['GAA']], y_fold47['Sv%'])
lin_reg48.fit(X_fold48[['GAA']], y_fold48['Sv%'])
lin_reg49.fit(X_fold49[['GAA']], y_fold49['Sv%'])
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions

# %%
linreg_pred0 = lin_reg0.predict(X_test_fold0[['GAA']])
linreg_pred1 = lin_reg1.predict(X_test_fold1[['GAA']])
linreg_pred2 = lin_reg2.predict(X_test_fold2[['GAA']])
linreg_pred3 = lin_reg3.predict(X_test_fold3[['GAA']])
linreg_pred4 = lin_reg4.predict(X_test_fold4[['GAA']])
linreg_pred5 = lin_reg5.predict(X_test_fold5[['GAA']])
linreg_pred6 = lin_reg6.predict(X_test_fold6[['GAA']])
linreg_pred7 = lin_reg7.predict(X_test_fold7[['GAA']])
linreg_pred8 = lin_reg8.predict(X_test_fold8[['GAA']])
linreg_pred9 = lin_reg9.predict(X_test_fold9[['GAA']])
linreg_pred10 = lin_reg10.predict(X_test_fold10[['GAA']])
linreg_pred11 = lin_reg11.predict(X_test_fold11[['GAA']])
linreg_pred12 = lin_reg12.predict(X_test_fold12[['GAA']])
linreg_pred13 = lin_reg13.predict(X_test_fold13[['GAA']])
linreg_pred14 = lin_reg14.predict(X_test_fold14[['GAA']])
linreg_pred15 = lin_reg15.predict(X_test_fold15[['GAA']])
linreg_pred16 = lin_reg16.predict(X_test_fold16[['GAA']])
linreg_pred17 = lin_reg17.predict(X_test_fold17[['GAA']])
linreg_pred18 = lin_reg18.predict(X_test_fold18[['GAA']])
linreg_pred19 = lin_reg19.predict(X_test_fold19[['GAA']])
linreg_pred20 = lin_reg20.predict(X_test_fold20[['GAA']])
linreg_pred21 = lin_reg21.predict(X_test_fold21[['GAA']])
linreg_pred22 = lin_reg22.predict(X_test_fold22[['GAA']])
linreg_pred23 = lin_reg23.predict(X_test_fold23[['GAA']])
linreg_pred24 = lin_reg24.predict(X_test_fold24[['GAA']])
linreg_pred25 = lin_reg25.predict(X_test_fold25[['GAA']])
linreg_pred26 = lin_reg26.predict(X_test_fold26[['GAA']])
linreg_pred27 = lin_reg27.predict(X_test_fold27[['GAA']])
linreg_pred28 = lin_reg28.predict(X_test_fold28[['GAA']])
linreg_pred29 = lin_reg29.predict(X_test_fold29[['GAA']])
linreg_pred30 = lin_reg30.predict(X_test_fold30[['GAA']])
linreg_pred31 = lin_reg31.predict(X_test_fold31[['GAA']])
linreg_pred32 = lin_reg32.predict(X_test_fold32[['GAA']])
linreg_pred33 = lin_reg33.predict(X_test_fold33[['GAA']])
linreg_pred34 = lin_reg34.predict(X_test_fold34[['GAA']])
linreg_pred35 = lin_reg35.predict(X_test_fold35[['GAA']])
linreg_pred36 = lin_reg36.predict(X_test_fold36[['GAA']])
linreg_pred37 = lin_reg37.predict(X_test_fold37[['GAA']])
linreg_pred38 = lin_reg38.predict(X_test_fold38[['GAA']])
linreg_pred39 = lin_reg39.predict(X_test_fold39[['GAA']])
linreg_pred40 = lin_reg40.predict(X_test_fold40[['GAA']])
linreg_pred41 = lin_reg41.predict(X_test_fold41[['GAA']])
linreg_pred42 = lin_reg42.predict(X_test_fold42[['GAA']])
linreg_pred43 = lin_reg43.predict(X_test_fold43[['GAA']])
linreg_pred44 = lin_reg44.predict(X_test_fold44[['GAA']])
linreg_pred45 = lin_reg45.predict(X_test_fold45[['GAA']])
linreg_pred46 = lin_reg46.predict(X_test_fold46[['GAA']])
linreg_pred47 = lin_reg47.predict(X_test_fold47[['GAA']])
linreg_pred48 = lin_reg48.predict(X_test_fold48[['GAA']])
linreg_pred49 = lin_reg49.predict(X_test_fold49[['GAA']])

# %%
linreg_mses = [0]*50

mse = 0
mse_add = 0
y_test_fold0 = y_test_fold0.reset_index(drop = True)
for i in range(0, len(linreg_pred0)):
    mse_add = (linreg_pred0[i] - y_test_fold0['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[0] = mse

mse = 0
mse_add = 0
y_test_fold1 = y_test_fold1.reset_index(drop = True)
for i in range(0, len(linreg_pred1)):
    mse_add = (linreg_pred1[i] - y_test_fold1['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[1] = mse

mse = 0
mse_add = 0
y_test_fold2 = y_test_fold2.reset_index(drop = True)
for i in range(0, len(linreg_pred2)):
    mse_add = (linreg_pred2[i] - y_test_fold2['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[2] = mse

mse = 0
mse_add = 0
y_test_fold3 = y_test_fold3.reset_index(drop = True)
for i in range(0, len(linreg_pred3)):
    mse_add = (linreg_pred3[i] - y_test_fold3['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[3] = mse

mse = 0
mse_add = 0
y_test_fold4 = y_test_fold4.reset_index(drop = True)
for i in range(0, len(linreg_pred4)):
    mse_add = (linreg_pred4[i] - y_test_fold4['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[4] = mse

mse = 0
mse_add = 0
y_test_fold5 = y_test_fold5.reset_index(drop = True)
for i in range(0, len(linreg_pred5)):
    mse_add = (linreg_pred5[i] - y_test_fold5['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[5] = mse

mse = 0
mse_add = 0
y_test_fold6 = y_test_fold6.reset_index(drop = True)
for i in range(0, len(linreg_pred6)):
    mse_add = (linreg_pred6[i] - y_test_fold6['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[6] = mse

mse = 0
mse_add = 0
y_test_fold7 = y_test_fold7.reset_index(drop = True)
for i in range(0, len(linreg_pred7)):
    mse_add = (linreg_pred7[i] - y_test_fold7['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[7] = mse

mse = 0
mse_add = 0
y_test_fold8 = y_test_fold8.reset_index(drop = True)
for i in range(0, len(linreg_pred8)):
    mse_add = (linreg_pred8[i] - y_test_fold8['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[8] = mse

mse = 0
mse_add = 0
y_test_fold9 = y_test_fold9.reset_index(drop = True)
for i in range(0, len(linreg_pred9)):
    mse_add = (linreg_pred9[i] - y_test_fold9['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[9] = mse

mse = 0
mse_add = 0
y_test_fold10 = y_test_fold10.reset_index(drop = True)
for i in range(0, len(linreg_pred10)):
    mse_add = (linreg_pred10[i] - y_test_fold10['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[10] = mse

mse = 0
mse_add = 0
y_test_fold11 = y_test_fold11.reset_index(drop = True)
for i in range(0, len(linreg_pred11)):
    mse_add = (linreg_pred11[i] - y_test_fold11['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[11] = mse

mse = 0
mse_add = 0
y_test_fold12 = y_test_fold12.reset_index(drop = True)
for i in range(0, len(linreg_pred12)):
    mse_add = (linreg_pred12[i] - y_test_fold12['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[12] = mse

mse = 0
mse_add = 0
y_test_fold13 = y_test_fold13.reset_index(drop = True)
for i in range(0, len(linreg_pred13)):
    mse_add = (linreg_pred13[i] - y_test_fold13['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[13] = mse

mse = 0
mse_add = 0
y_test_fold14 = y_test_fold14.reset_index(drop = True)
for i in range(0, len(linreg_pred14)):
    mse_add = (linreg_pred14[i] - y_test_fold14['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[14] = mse

mse = 0
mse_add = 0
y_test_fold15 = y_test_fold15.reset_index(drop = True)
for i in range(0, len(linreg_pred15)):
    mse_add = (linreg_pred15[i] - y_test_fold15['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[15] = mse

mse = 0
mse_add = 0
y_test_fold16 = y_test_fold16.reset_index(drop = True)
for i in range(0, len(linreg_pred16)):
    mse_add = (linreg_pred16[i] - y_test_fold16['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[16] = mse

mse = 0
mse_add = 0
y_test_fold17 = y_test_fold17.reset_index(drop = True)
for i in range(0, len(linreg_pred17)):
    mse_add = (linreg_pred17[i] - y_test_fold17['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[17] = mse

mse = 0
mse_add = 0
y_test_fold18 = y_test_fold18.reset_index(drop = True)
for i in range(0, len(linreg_pred18)):
    mse_add = (linreg_pred18[i] - y_test_fold18['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[18] = mse

mse = 0
mse_add = 0
y_test_fold19 = y_test_fold19.reset_index(drop = True)
for i in range(0, len(linreg_pred19)):
    mse_add = (linreg_pred19[i] - y_test_fold19['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[19] = mse

mse = 0
mse_add = 0
y_test_fold20 = y_test_fold20.reset_index(drop = True)
for i in range(0, len(linreg_pred20)):
    mse_add = (linreg_pred20[i] - y_test_fold20['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[20] = mse

mse = 0
mse_add = 0
y_test_fold21 = y_test_fold21.reset_index(drop = True)
for i in range(0, len(linreg_pred21)):
    mse_add = (linreg_pred21[i] - y_test_fold21['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[21] = mse

mse = 0
mse_add = 0
y_test_fold22 = y_test_fold22.reset_index(drop = True)
for i in range(0, len(linreg_pred22)):
    mse_add = (linreg_pred22[i] - y_test_fold22['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[22] = mse

mse = 0
mse_add = 0
y_test_fold23 = y_test_fold23.reset_index(drop = True)
for i in range(0, len(linreg_pred23)):
    mse_add = (linreg_pred23[i] - y_test_fold23['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[23] = mse

mse = 0
mse_add = 0
y_test_fold24 = y_test_fold24.reset_index(drop = True)
for i in range(0, len(linreg_pred24)):
    mse_add = (linreg_pred24[i] - y_test_fold24['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[24] = mse

mse = 0
mse_add = 0
y_test_fold25 = y_test_fold25.reset_index(drop = True)
for i in range(0, len(linreg_pred25)):
    mse_add = (linreg_pred25[i] - y_test_fold25['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[25] = mse

mse = 0
mse_add = 0
y_test_fold26 = y_test_fold26.reset_index(drop = True)
for i in range(0, len(linreg_pred26)):
    mse_add = (linreg_pred26[i] - y_test_fold26['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[26] = mse

mse = 0
mse_add = 0
y_test_fold27 = y_test_fold27.reset_index(drop = True)
for i in range(0, len(linreg_pred27)):
    mse_add = (linreg_pred27[i] - y_test_fold27['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[27] = mse

mse = 0
mse_add = 0
y_test_fold28 = y_test_fold28.reset_index(drop = True)
for i in range(0, len(linreg_pred28)):
    mse_add = (linreg_pred28[i] - y_test_fold28['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[28] = mse

mse = 0
mse_add = 0
y_test_fold29 = y_test_fold29.reset_index(drop = True)
for i in range(0, len(linreg_pred29)):
    mse_add = (linreg_pred29[i] - y_test_fold29['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[29] = mse

mse = 0
mse_add = 0
y_test_fold30 = y_test_fold30.reset_index(drop = True)
for i in range(0, len(linreg_pred30)):
    mse_add = (linreg_pred30[i] - y_test_fold30['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[30] = mse

mse = 0
mse_add = 0
y_test_fold31 = y_test_fold31.reset_index(drop = True)
for i in range(0, len(linreg_pred31)):
    mse_add = (linreg_pred31[i] - y_test_fold31['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[31] = mse

mse = 0
mse_add = 0
y_test_fold32 = y_test_fold32.reset_index(drop = True)
for i in range(0, len(linreg_pred32)):
    mse_add = (linreg_pred32[i] - y_test_fold32['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[32] = mse

mse = 0
mse_add = 0
y_test_fold33 = y_test_fold33.reset_index(drop = True)
for i in range(0, len(linreg_pred33)):
    mse_add = (linreg_pred33[i] - y_test_fold33['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[33] = mse

mse = 0
mse_add = 0
y_test_fold34 = y_test_fold34.reset_index(drop = True)
for i in range(0, len(linreg_pred34)):
    mse_add = (linreg_pred34[i] - y_test_fold34['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[34] = mse

mse = 0
mse_add = 0
y_test_fold35 = y_test_fold35.reset_index(drop = True)
for i in range(0, len(linreg_pred35)):
    mse_add = (linreg_pred35[i] - y_test_fold35['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[35] = mse

mse = 0
mse_add = 0
y_test_fold36 = y_test_fold36.reset_index(drop = True)
for i in range(0, len(linreg_pred36)):
    mse_add = (linreg_pred36[i] - y_test_fold36['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[36] = mse

mse = 0
mse_add = 0
y_test_fold37 = y_test_fold37.reset_index(drop = True)
for i in range(0, len(linreg_pred37)):
    mse_add = (linreg_pred37[i] - y_test_fold37['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[37] = mse

mse = 0
mse_add = 0
y_test_fold38 = y_test_fold38.reset_index(drop = True)
for i in range(0, len(linreg_pred38)):
    mse_add = (linreg_pred38[i] - y_test_fold38['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[38] = mse

mse = 0
mse_add = 0
y_test_fold39 = y_test_fold39.reset_index(drop = True)
for i in range(0, len(linreg_pred39)):
    mse_add = (linreg_pred39[i] - y_test_fold39['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[39] = mse

mse = 0
mse_add = 0
y_test_fold40 = y_test_fold40.reset_index(drop = True)
for i in range(0, len(linreg_pred40)):
    mse_add = (linreg_pred40[i] - y_test_fold40['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[40] = mse

mse = 0
mse_add = 0
y_test_fold41 = y_test_fold41.reset_index(drop = True)
for i in range(0, len(linreg_pred41)):
    mse_add = (linreg_pred41[i] - y_test_fold41['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[41] = mse

mse = 0
mse_add = 0
y_test_fold42 = y_test_fold42.reset_index(drop = True)
for i in range(0, len(linreg_pred42)):
    mse_add = (linreg_pred42[i] - y_test_fold42['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[42] = mse

mse = 0
mse_add = 0
y_test_fold43 = y_test_fold43.reset_index(drop = True)
for i in range(0, len(linreg_pred43)):
    mse_add = (linreg_pred43[i] - y_test_fold43['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[43] = mse

mse = 0
mse_add = 0
y_test_fold44 = y_test_fold44.reset_index(drop = True)
for i in range(0, len(linreg_pred44)):
    mse_add = (linreg_pred44[i] - y_test_fold44['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[44] = mse

mse = 0
mse_add = 0
y_test_fold45 = y_test_fold45.reset_index(drop = True)
for i in range(0, len(linreg_pred45)):
    mse_add = (linreg_pred45[i] - y_test_fold45['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[45] = mse

mse = 0
mse_add = 0
y_test_fold46 = y_test_fold46.reset_index(drop = True)
for i in range(0, len(linreg_pred46)):
    mse_add = (linreg_pred46[i] - y_test_fold46['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[46] = mse

mse = 0
mse_add = 0
y_test_fold47 = y_test_fold47.reset_index(drop = True)
for i in range(0, len(linreg_pred47)):
    mse_add = (linreg_pred47[i] - y_test_fold47['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[47] = mse

mse = 0
mse_add = 0
y_test_fold48 = y_test_fold48.reset_index(drop = True)
for i in range(0, len(linreg_pred48)):
    mse_add = (linreg_pred48[i] - y_test_fold48['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[48] = mse

mse = 0
mse_add = 0
y_test_fold49 = y_test_fold49.reset_index(drop = True)
for i in range(0, len(linreg_pred49)):
    mse_add = (linreg_pred49[i] - y_test_fold49['Sv%'][i]) ** 2
    mse = mse + mse_add
linreg_mses[49] = mse

# %% [markdown]
# # Linear Regression MSE

# %%
linreg_mse = sum(linreg_mses) / len(linreg_mses)
linreg_mse
# Out:
# 0.0031022180285230246

# %% [markdown]
# ## Support Vector Regression

# %%
svr0 = SVR(kernel = 'rbf')
svr1 = SVR(kernel = 'rbf')
svr2 = SVR(kernel = 'rbf')
svr3 = SVR(kernel = 'rbf')
svr4 = SVR(kernel = 'rbf')
svr5 = SVR(kernel = 'rbf')
svr6 = SVR(kernel = 'rbf')
svr7 = SVR(kernel = 'rbf')
svr8 = SVR(kernel = 'rbf')
svr9 = SVR(kernel = 'rbf')
svr10 = SVR(kernel = 'rbf')
svr11 = SVR(kernel = 'rbf')
svr12 = SVR(kernel = 'rbf')
svr13 = SVR(kernel = 'rbf')
svr14 = SVR(kernel = 'rbf')
svr15 = SVR(kernel = 'rbf')
svr16 = SVR(kernel = 'rbf')
svr17 = SVR(kernel = 'rbf')
svr18 = SVR(kernel = 'rbf')
svr19 = SVR(kernel = 'rbf')
svr20 = SVR(kernel = 'rbf')
svr21 = SVR(kernel = 'rbf')
svr22 = SVR(kernel = 'rbf')
svr23 = SVR(kernel = 'rbf')
svr24 = SVR(kernel = 'rbf')
svr25 = SVR(kernel = 'rbf')
svr26 = SVR(kernel = 'rbf')
svr27 = SVR(kernel = 'rbf')
svr28 = SVR(kernel = 'rbf')
svr29 = SVR(kernel = 'rbf')
svr30 = SVR(kernel = 'rbf')
svr31 = SVR(kernel = 'rbf')
svr32 = SVR(kernel = 'rbf')
svr33 = SVR(kernel = 'rbf')
svr34 = SVR(kernel = 'rbf')
svr35 = SVR(kernel = 'rbf')
svr36 = SVR(kernel = 'rbf')
svr37 = SVR(kernel = 'rbf')
svr38 = SVR(kernel = 'rbf')
svr39 = SVR(kernel = 'rbf')
svr40 = SVR(kernel = 'rbf')
svr41 = SVR(kernel = 'rbf')
svr42 = SVR(kernel = 'rbf')
svr43 = SVR(kernel = 'rbf')
svr44 = SVR(kernel = 'rbf')
svr45 = SVR(kernel = 'rbf')
svr46 = SVR(kernel = 'rbf')
svr47 = SVR(kernel = 'rbf')
svr48 = SVR(kernel = 'rbf')
svr49 = SVR(kernel = 'rbf')

# %%
svr0.fit(X_fold0[['GAA']], y_fold0['Sv%'])
svr1.fit(X_fold1[['GAA']], y_fold1['Sv%'])
svr2.fit(X_fold2[['GAA']], y_fold2['Sv%'])
svr3.fit(X_fold3[['GAA']], y_fold3['Sv%'])
svr4.fit(X_fold4[['GAA']], y_fold4['Sv%'])
svr5.fit(X_fold5[['GAA']], y_fold5['Sv%'])
svr6.fit(X_fold6[['GAA']], y_fold6['Sv%'])
svr7.fit(X_fold7[['GAA']], y_fold7['Sv%'])
svr8.fit(X_fold8[['GAA']], y_fold8['Sv%'])
svr9.fit(X_fold9[['GAA']], y_fold9['Sv%'])
svr10.fit(X_fold10[['GAA']], y_fold10['Sv%'])
svr11.fit(X_fold11[['GAA']], y_fold11['Sv%'])
svr12.fit(X_fold12[['GAA']], y_fold12['Sv%'])
svr13.fit(X_fold13[['GAA']], y_fold13['Sv%'])
svr14.fit(X_fold14[['GAA']], y_fold14['Sv%'])
svr15.fit(X_fold15[['GAA']], y_fold15['Sv%'])
svr16.fit(X_fold16[['GAA']], y_fold16['Sv%'])
svr17.fit(X_fold17[['GAA']], y_fold17['Sv%'])
svr18.fit(X_fold18[['GAA']], y_fold18['Sv%'])
svr19.fit(X_fold19[['GAA']], y_fold19['Sv%'])
svr20.fit(X_fold20[['GAA']], y_fold20['Sv%'])
svr21.fit(X_fold21[['GAA']], y_fold21['Sv%'])
svr22.fit(X_fold22[['GAA']], y_fold22['Sv%'])
svr23.fit(X_fold23[['GAA']], y_fold23['Sv%'])
svr24.fit(X_fold24[['GAA']], y_fold24['Sv%'])
svr25.fit(X_fold25[['GAA']], y_fold25['Sv%'])
svr26.fit(X_fold26[['GAA']], y_fold26['Sv%'])
svr27.fit(X_fold27[['GAA']], y_fold27['Sv%'])
svr28.fit(X_fold28[['GAA']], y_fold28['Sv%'])
svr29.fit(X_fold29[['GAA']], y_fold29['Sv%'])
svr30.fit(X_fold30[['GAA']], y_fold30['Sv%'])
svr31.fit(X_fold31[['GAA']], y_fold31['Sv%'])
svr32.fit(X_fold32[['GAA']], y_fold32['Sv%'])
svr33.fit(X_fold33[['GAA']], y_fold33['Sv%'])
svr34.fit(X_fold34[['GAA']], y_fold34['Sv%'])
svr35.fit(X_fold35[['GAA']], y_fold35['Sv%'])
svr36.fit(X_fold36[['GAA']], y_fold36['Sv%'])
svr37.fit(X_fold37[['GAA']], y_fold37['Sv%'])
svr38.fit(X_fold38[['GAA']], y_fold38['Sv%'])
svr39.fit(X_fold39[['GAA']], y_fold39['Sv%'])
svr40.fit(X_fold40[['GAA']], y_fold40['Sv%'])
svr41.fit(X_fold41[['GAA']], y_fold41['Sv%'])
svr42.fit(X_fold42[['GAA']], y_fold42['Sv%'])
svr43.fit(X_fold43[['GAA']], y_fold43['Sv%'])
svr44.fit(X_fold44[['GAA']], y_fold44['Sv%'])
svr45.fit(X_fold45[['GAA']], y_fold45['Sv%'])
svr46.fit(X_fold46[['GAA']], y_fold46['Sv%'])
svr47.fit(X_fold47[['GAA']], y_fold47['Sv%'])
svr48.fit(X_fold48[['GAA']], y_fold48['Sv%'])
svr49.fit(X_fold49[['GAA']], y_fold49['Sv%'])
# Out:
# SVR()

# %% [markdown]
# ### Make Predictions

# %%
svr_pred0 = svr0.predict(X_test_fold0[['GAA']])
svr_pred1 = svr1.predict(X_test_fold1[['GAA']])
svr_pred2 = svr2.predict(X_test_fold2[['GAA']])
svr_pred3 = svr3.predict(X_test_fold3[['GAA']])
svr_pred4 = svr4.predict(X_test_fold4[['GAA']])
svr_pred5 = svr5.predict(X_test_fold5[['GAA']])
svr_pred6 = svr6.predict(X_test_fold6[['GAA']])
svr_pred7 = svr7.predict(X_test_fold7[['GAA']])
svr_pred8 = svr8.predict(X_test_fold8[['GAA']])
svr_pred9 = svr9.predict(X_test_fold9[['GAA']])
svr_pred10 = svr10.predict(X_test_fold10[['GAA']])
svr_pred11 = svr11.predict(X_test_fold11[['GAA']])
svr_pred12 = svr12.predict(X_test_fold12[['GAA']])
svr_pred13 = svr13.predict(X_test_fold13[['GAA']])
svr_pred14 = svr14.predict(X_test_fold14[['GAA']])
svr_pred15 = svr15.predict(X_test_fold15[['GAA']])
svr_pred16 = svr16.predict(X_test_fold16[['GAA']])
svr_pred17 = svr17.predict(X_test_fold17[['GAA']])
svr_pred18 = svr18.predict(X_test_fold18[['GAA']])
svr_pred19 = svr19.predict(X_test_fold19[['GAA']])
svr_pred20 = svr20.predict(X_test_fold20[['GAA']])
svr_pred21 = svr21.predict(X_test_fold21[['GAA']])
svr_pred22 = svr22.predict(X_test_fold22[['GAA']])
svr_pred23 = svr23.predict(X_test_fold23[['GAA']])
svr_pred24 = svr24.predict(X_test_fold24[['GAA']])
svr_pred25 = svr25.predict(X_test_fold25[['GAA']])
svr_pred26 = svr26.predict(X_test_fold26[['GAA']])
svr_pred27 = svr27.predict(X_test_fold27[['GAA']])
svr_pred28 = svr28.predict(X_test_fold28[['GAA']])
svr_pred29 = svr29.predict(X_test_fold29[['GAA']])
svr_pred30 = svr30.predict(X_test_fold30[['GAA']])
svr_pred31 = svr31.predict(X_test_fold31[['GAA']])
svr_pred32 = svr32.predict(X_test_fold32[['GAA']])
svr_pred33 = svr33.predict(X_test_fold33[['GAA']])
svr_pred34 = svr34.predict(X_test_fold34[['GAA']])
svr_pred35 = svr35.predict(X_test_fold35[['GAA']])
svr_pred36 = svr36.predict(X_test_fold36[['GAA']])
svr_pred37 = svr37.predict(X_test_fold37[['GAA']])
svr_pred38 = svr38.predict(X_test_fold38[['GAA']])
svr_pred39 = svr39.predict(X_test_fold39[['GAA']])
svr_pred40 = svr40.predict(X_test_fold40[['GAA']])
svr_pred41 = svr41.predict(X_test_fold41[['GAA']])
svr_pred42 = svr42.predict(X_test_fold42[['GAA']])
svr_pred43 = svr43.predict(X_test_fold43[['GAA']])
svr_pred44 = svr44.predict(X_test_fold44[['GAA']])
svr_pred45 = svr45.predict(X_test_fold45[['GAA']])
svr_pred46 = svr46.predict(X_test_fold46[['GAA']])
svr_pred47 = svr47.predict(X_test_fold47[['GAA']])
svr_pred48 = svr48.predict(X_test_fold48[['GAA']])
svr_pred49 = svr49.predict(X_test_fold49[['GAA']])

# %%
svr_mses = [0]*50

mse = 0
mse_add = 0
y_test_fold0 = y_test_fold0.reset_index(drop = True)
for i in range(0, len(svr_pred0)):
    mse_add = (svr_pred0[i] - y_test_fold0['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[0] = mse

mse = 0
mse_add = 0
y_test_fold1 = y_test_fold1.reset_index(drop = True)
for i in range(0, len(svr_pred1)):
    mse_add = (svr_pred1[i] - y_test_fold1['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[1] = mse

mse = 0
mse_add = 0
y_test_fold2 = y_test_fold2.reset_index(drop = True)
for i in range(0, len(svr_pred2)):
    mse_add = (svr_pred2[i] - y_test_fold2['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[2] = mse

mse = 0
mse_add = 0
y_test_fold3 = y_test_fold3.reset_index(drop = True)
for i in range(0, len(svr_pred3)):
    mse_add = (svr_pred3[i] - y_test_fold3['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[3] = mse

mse = 0
mse_add = 0
y_test_fold4 = y_test_fold4.reset_index(drop = True)
for i in range(0, len(svr_pred4)):
    mse_add = (svr_pred4[i] - y_test_fold4['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[4] = mse

mse = 0
mse_add = 0
y_test_fold5 = y_test_fold5.reset_index(drop = True)
for i in range(0, len(svr_pred5)):
    mse_add = (svr_pred5[i] - y_test_fold5['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[5] = mse

mse = 0
mse_add = 0
y_test_fold6 = y_test_fold6.reset_index(drop = True)
for i in range(0, len(svr_pred6)):
    mse_add = (svr_pred6[i] - y_test_fold6['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[6] = mse

mse = 0
mse_add = 0
y_test_fold7 = y_test_fold7.reset_index(drop = True)
for i in range(0, len(svr_pred7)):
    mse_add = (svr_pred7[i] - y_test_fold7['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[7] = mse

mse = 0
mse_add = 0
y_test_fold8 = y_test_fold8.reset_index(drop = True)
for i in range(0, len(svr_pred8)):
    mse_add = (svr_pred8[i] - y_test_fold8['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[8] = mse

mse = 0
mse_add = 0
y_test_fold9 = y_test_fold9.reset_index(drop = True)
for i in range(0, len(svr_pred9)):
    mse_add = (svr_pred9[i] - y_test_fold9['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[9] = mse

mse = 0
mse_add = 0
y_test_fold10 = y_test_fold10.reset_index(drop = True)
for i in range(0, len(svr_pred10)):
    mse_add = (svr_pred10[i] - y_test_fold10['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[10] = mse

mse = 0
mse_add = 0
y_test_fold11 = y_test_fold11.reset_index(drop = True)
for i in range(0, len(svr_pred11)):
    mse_add = (svr_pred11[i] - y_test_fold11['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[11] = mse

mse = 0
mse_add = 0
y_test_fold12 = y_test_fold12.reset_index(drop = True)
for i in range(0, len(svr_pred12)):
    mse_add = (svr_pred12[i] - y_test_fold12['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[12] = mse

mse = 0
mse_add = 0
y_test_fold13 = y_test_fold13.reset_index(drop = True)
for i in range(0, len(svr_pred13)):
    mse_add = (svr_pred13[i] - y_test_fold13['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[13] = mse

mse = 0
mse_add = 0
y_test_fold14 = y_test_fold14.reset_index(drop = True)
for i in range(0, len(svr_pred14)):
    mse_add = (svr_pred14[i] - y_test_fold14['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[14] = mse

mse = 0
mse_add = 0
y_test_fold15 = y_test_fold15.reset_index(drop = True)
for i in range(0, len(svr_pred15)):
    mse_add = (svr_pred15[i] - y_test_fold15['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[15] = mse

mse = 0
mse_add = 0
y_test_fold16 = y_test_fold16.reset_index(drop = True)
for i in range(0, len(svr_pred16)):
    mse_add = (svr_pred16[i] - y_test_fold16['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[16] = mse

mse = 0
mse_add = 0
y_test_fold17 = y_test_fold17.reset_index(drop = True)
for i in range(0, len(svr_pred17)):
    mse_add = (svr_pred17[i] - y_test_fold17['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[17] = mse

mse = 0
mse_add = 0
y_test_fold18 = y_test_fold18.reset_index(drop = True)
for i in range(0, len(svr_pred18)):
    mse_add = (svr_pred18[i] - y_test_fold18['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[18] = mse

mse = 0
mse_add = 0
y_test_fold19 = y_test_fold19.reset_index(drop = True)
for i in range(0, len(svr_pred19)):
    mse_add = (svr_pred19[i] - y_test_fold19['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[19] = mse

mse = 0
mse_add = 0
y_test_fold20 = y_test_fold20.reset_index(drop = True)
for i in range(0, len(svr_pred20)):
    mse_add = (svr_pred20[i] - y_test_fold20['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[20] = mse

mse = 0
mse_add = 0
y_test_fold21 = y_test_fold21.reset_index(drop = True)
for i in range(0, len(svr_pred21)):
    mse_add = (svr_pred21[i] - y_test_fold21['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[21] = mse

mse = 0
mse_add = 0
y_test_fold22 = y_test_fold22.reset_index(drop = True)
for i in range(0, len(svr_pred22)):
    mse_add = (svr_pred22[i] - y_test_fold22['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[22] = mse

mse = 0
mse_add = 0
y_test_fold23 = y_test_fold23.reset_index(drop = True)
for i in range(0, len(svr_pred23)):
    mse_add = (svr_pred23[i] - y_test_fold23['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[23] = mse

mse = 0
mse_add = 0
y_test_fold24 = y_test_fold24.reset_index(drop = True)
for i in range(0, len(svr_pred24)):
    mse_add = (svr_pred24[i] - y_test_fold24['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[24] = mse

mse = 0
mse_add = 0
y_test_fold25 = y_test_fold25.reset_index(drop = True)
for i in range(0, len(svr_pred25)):
    mse_add = (svr_pred25[i] - y_test_fold25['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[25] = mse

mse = 0
mse_add = 0
y_test_fold26 = y_test_fold26.reset_index(drop = True)
for i in range(0, len(svr_pred26)):
    mse_add = (svr_pred26[i] - y_test_fold26['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[26] = mse

mse = 0
mse_add = 0
y_test_fold27 = y_test_fold27.reset_index(drop = True)
for i in range(0, len(svr_pred27)):
    mse_add = (svr_pred27[i] - y_test_fold27['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[27] = mse

mse = 0
mse_add = 0
y_test_fold28 = y_test_fold28.reset_index(drop = True)
for i in range(0, len(svr_pred28)):
    mse_add = (svr_pred28[i] - y_test_fold28['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[28] = mse

mse = 0
mse_add = 0
y_test_fold29 = y_test_fold29.reset_index(drop = True)
for i in range(0, len(svr_pred29)):
    mse_add = (svr_pred29[i] - y_test_fold29['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[29] = mse

mse = 0
mse_add = 0
y_test_fold30 = y_test_fold30.reset_index(drop = True)
for i in range(0, len(svr_pred30)):
    mse_add = (svr_pred30[i] - y_test_fold30['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[30] = mse

mse = 0
mse_add = 0
y_test_fold31 = y_test_fold31.reset_index(drop = True)
for i in range(0, len(svr_pred31)):
    mse_add = (svr_pred31[i] - y_test_fold31['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[31] = mse

mse = 0
mse_add = 0
y_test_fold32 = y_test_fold32.reset_index(drop = True)
for i in range(0, len(svr_pred32)):
    mse_add = (svr_pred32[i] - y_test_fold32['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[32] = mse

mse = 0
mse_add = 0
y_test_fold33 = y_test_fold33.reset_index(drop = True)
for i in range(0, len(svr_pred33)):
    mse_add = (svr_pred33[i] - y_test_fold33['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[33] = mse

mse = 0
mse_add = 0
y_test_fold34 = y_test_fold34.reset_index(drop = True)
for i in range(0, len(svr_pred34)):
    mse_add = (svr_pred34[i] - y_test_fold34['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[34] = mse

mse = 0
mse_add = 0
y_test_fold35 = y_test_fold35.reset_index(drop = True)
for i in range(0, len(svr_pred35)):
    mse_add = (svr_pred35[i] - y_test_fold35['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[35] = mse

mse = 0
mse_add = 0
y_test_fold36 = y_test_fold36.reset_index(drop = True)
for i in range(0, len(svr_pred36)):
    mse_add = (svr_pred36[i] - y_test_fold36['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[36] = mse

mse = 0
mse_add = 0
y_test_fold37 = y_test_fold37.reset_index(drop = True)
for i in range(0, len(svr_pred37)):
    mse_add = (svr_pred37[i] - y_test_fold37['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[37] = mse

mse = 0
mse_add = 0
y_test_fold38 = y_test_fold38.reset_index(drop = True)
for i in range(0, len(svr_pred38)):
    mse_add = (svr_pred38[i] - y_test_fold38['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[38] = mse

mse = 0
mse_add = 0
y_test_fold39 = y_test_fold39.reset_index(drop = True)
for i in range(0, len(svr_pred39)):
    mse_add = (svr_pred39[i] - y_test_fold39['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[39] = mse

mse = 0
mse_add = 0
y_test_fold40 = y_test_fold40.reset_index(drop = True)
for i in range(0, len(svr_pred40)):
    mse_add = (svr_pred40[i] - y_test_fold40['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[40] = mse

mse = 0
mse_add = 0
y_test_fold41 = y_test_fold41.reset_index(drop = True)
for i in range(0, len(svr_pred41)):
    mse_add = (svr_pred41[i] - y_test_fold41['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[41] = mse

mse = 0
mse_add = 0
y_test_fold42 = y_test_fold42.reset_index(drop = True)
for i in range(0, len(svr_pred42)):
    mse_add = (svr_pred42[i] - y_test_fold42['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[42] = mse

mse = 0
mse_add = 0
y_test_fold43 = y_test_fold43.reset_index(drop = True)
for i in range(0, len(svr_pred43)):
    mse_add = (svr_pred43[i] - y_test_fold43['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[43] = mse

mse = 0
mse_add = 0
y_test_fold44 = y_test_fold44.reset_index(drop = True)
for i in range(0, len(svr_pred44)):
    mse_add = (svr_pred44[i] - y_test_fold44['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[44] = mse

mse = 0
mse_add = 0
y_test_fold45 = y_test_fold45.reset_index(drop = True)
for i in range(0, len(svr_pred45)):
    mse_add = (svr_pred45[i] - y_test_fold45['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[45] = mse

mse = 0
mse_add = 0
y_test_fold46 = y_test_fold46.reset_index(drop = True)
for i in range(0, len(svr_pred46)):
    mse_add = (svr_pred46[i] - y_test_fold46['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[46] = mse

mse = 0
mse_add = 0
y_test_fold47 = y_test_fold47.reset_index(drop = True)
for i in range(0, len(svr_pred47)):
    mse_add = (svr_pred47[i] - y_test_fold47['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[47] = mse

mse = 0
mse_add = 0
y_test_fold48 = y_test_fold48.reset_index(drop = True)
for i in range(0, len(svr_pred48)):
    mse_add = (svr_pred48[i] - y_test_fold48['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[48] = mse

mse = 0
mse_add = 0
y_test_fold49 = y_test_fold49.reset_index(drop = True)
for i in range(0, len(svr_pred49)):
    mse_add = (svr_pred49[i] - y_test_fold49['Sv%'][i]) ** 2
    mse = mse + mse_add
svr_mses[49] = mse

# %% [markdown]
# # Support Vector Regression MSE

# %%
svr_mse = sum(svr_mses) / len(svr_mses)
svr_mse
# Out:
# 0.01930162499999999

# %% [markdown]
# # Fit Linear Regression

# %%
# Get Coefficients
coefs = [0]*50
coefs[0] = lin_reg0.coef_
coefs[1] = lin_reg1.coef_
coefs[2] = lin_reg2.coef_
coefs[3] = lin_reg3.coef_
coefs[4] = lin_reg4.coef_
coefs[5] = lin_reg5.coef_
coefs[6] = lin_reg6.coef_
coefs[7] = lin_reg7.coef_
coefs[8] = lin_reg8.coef_
coefs[9] = lin_reg9.coef_
coefs[10] = lin_reg10.coef_
coefs[11] = lin_reg11.coef_
coefs[12] = lin_reg12.coef_
coefs[13] = lin_reg13.coef_
coefs[14] = lin_reg14.coef_
coefs[15] = lin_reg15.coef_
coefs[16] = lin_reg16.coef_
coefs[17] = lin_reg17.coef_
coefs[18] = lin_reg18.coef_
coefs[19] = lin_reg19.coef_
coefs[20] = lin_reg20.coef_
coefs[21] = lin_reg21.coef_
coefs[22] = lin_reg22.coef_
coefs[23] = lin_reg23.coef_
coefs[24] = lin_reg24.coef_
coefs[25] = lin_reg25.coef_
coefs[26] = lin_reg26.coef_
coefs[27] = lin_reg27.coef_
coefs[28] = lin_reg28.coef_
coefs[29] = lin_reg29.coef_
coefs[30] = lin_reg30.coef_
coefs[31] = lin_reg31.coef_
coefs[32] = lin_reg32.coef_
coefs[33] = lin_reg33.coef_
coefs[34] = lin_reg34.coef_
coefs[35] = lin_reg35.coef_
coefs[36] = lin_reg36.coef_
coefs[37] = lin_reg37.coef_
coefs[38] = lin_reg38.coef_
coefs[39] = lin_reg39.coef_
coefs[40] = lin_reg40.coef_
coefs[41] = lin_reg41.coef_
coefs[42] = lin_reg42.coef_
coefs[43] = lin_reg43.coef_
coefs[44] = lin_reg44.coef_
coefs[45] = lin_reg45.coef_
coefs[46] = lin_reg46.coef_
coefs[47] = lin_reg47.coef_
coefs[48] = lin_reg48.coef_
coefs[49] = lin_reg49.coef_

# %%
#Get Intercept
inter = [0]*50
inter[0] = lin_reg0.intercept_
inter[1] = lin_reg1.intercept_
inter[2] = lin_reg2.intercept_
inter[3] = lin_reg3.intercept_
inter[4] = lin_reg4.intercept_
inter[5] = lin_reg5.intercept_
inter[6] = lin_reg6.intercept_
inter[7] = lin_reg7.intercept_
inter[8] = lin_reg8.intercept_
inter[9] = lin_reg9.intercept_
inter[10] = lin_reg10.intercept_
inter[11] = lin_reg11.intercept_
inter[12] = lin_reg12.intercept_
inter[13] = lin_reg13.intercept_
inter[14] = lin_reg14.intercept_
inter[15] = lin_reg15.intercept_
inter[16] = lin_reg16.intercept_
inter[17] = lin_reg17.intercept_
inter[18] = lin_reg18.intercept_
inter[19] = lin_reg19.intercept_
inter[20] = lin_reg20.intercept_
inter[21] = lin_reg21.intercept_
inter[22] = lin_reg22.intercept_
inter[23] = lin_reg23.intercept_
inter[24] = lin_reg24.intercept_
inter[25] = lin_reg25.intercept_
inter[26] = lin_reg26.intercept_
inter[27] = lin_reg27.intercept_
inter[28] = lin_reg28.intercept_
inter[29] = lin_reg29.intercept_
inter[30] = lin_reg30.intercept_
inter[31] = lin_reg31.intercept_
inter[32] = lin_reg32.intercept_
inter[33] = lin_reg33.intercept_
inter[34] = lin_reg34.intercept_
inter[35] = lin_reg35.intercept_
inter[36] = lin_reg36.intercept_
inter[37] = lin_reg37.intercept_
inter[38] = lin_reg38.intercept_
inter[39] = lin_reg39.intercept_
inter[40] = lin_reg40.intercept_
inter[41] = lin_reg41.intercept_
inter[42] = lin_reg42.intercept_
inter[43] = lin_reg43.intercept_
inter[44] = lin_reg44.intercept_
inter[45] = lin_reg45.intercept_
inter[46] = lin_reg46.intercept_
inter[47] = lin_reg47.intercept_
inter[48] = lin_reg48.intercept_
inter[49] = lin_reg49.intercept_

# %%
#Get 95% Confidence Intervals For Each Fold

u_inter = [0]*50
l_inter = [0]*50
u_coeff = [0]*50
l_coeff = [0]*50

coeff0 = coefs[0]
intercept0 = inter[0]
N0 = len(X_fold0[['GAA']])
p0 = 2
X_with_intercept0 = np.empty(shape = (N0, p0), dtype = np.float)
X_with_intercept0[:, 0] = 1
X_with_intercept0[:, 1 : p0] = X_fold0[['GAA']].values
y_hat0 = lin_reg0.predict(X_fold0[['GAA']])
residuals0 = y_fold0['Sv%'].values - y_hat0
residual_sum_of_squares0 = residuals0.T @ residuals0
sigma_squared_hat0 = residual_sum_of_squares0 / (N0 - p0)
var_beta_hat0 = np.linalg.inv(X_with_intercept0.T @ X_with_intercept0) * sigma_squared_hat0
u_inter[0] = intercept0 + 1.96 * (var_beta_hat0[0, 0] ** 0.5)
u_coeff[0] = coeff0 + 1.96 * (var_beta_hat0[1, 1] ** 0.5)
l_inter[0] = intercept0 - 1.96 * (var_beta_hat0[0, 0] ** 0.5)
l_coeff[0] = coeff0 - 1.96 * (var_beta_hat0[1, 1] ** 0.5)

coeff1 = coefs[1]
intercept1 = inter[1]
N1 = len(X_fold1[['GAA']])
p1 = 2
X_with_intercept1 = np.empty(shape = (N0, p0), dtype = np.float)
X_with_intercept1[:, 0] = 1
X_with_intercept1[:, 1 : p0] = X_fold1[['GAA']].values
y_hat1 = lin_reg1.predict(X_fold1[['GAA']])
residuals1 = y_fold1['Sv%'].values - y_hat1
residual_sum_of_squares1 = residuals1.T @ residuals1
sigma_squared_hat1 = residual_sum_of_squares1 / (N1 - p1)
var_beta_hat1 = np.linalg.inv(X_with_intercept1.T @ X_with_intercept1) * sigma_squared_hat1
u_inter[1] = intercept1 + 1.96 * (var_beta_hat1[0, 0] ** 0.5)
u_coeff[1] = coeff1 + 1.96 * (var_beta_hat1[1, 1] ** 0.5)
l_inter[1] = intercept1 - 1.96 * (var_beta_hat1[0, 0] ** 0.5)
l_coeff[1] = coeff1 - 1.96 * (var_beta_hat1[1, 1] ** 0.5)

coeff2 = coefs[2]
intercept2 = inter[2]
N2 = len(X_fold2[['GAA']])
p2 = 2
X_with_intercept2 = np.empty(shape = (N2, p2), dtype = np.float)
X_with_intercept2[:, 0] = 1
X_with_intercept2[:, 1 : p2] = X_fold2[['GAA']].values
y_hat2 = lin_reg2.predict(X_fold2[['GAA']])
residuals2 = y_fold2['Sv%'].values - y_hat2
residual_sum_of_squares2 = residuals2.T @ residuals2
sigma_squared_hat2 = residual_sum_of_squares2 / (N2 - p2)
var_beta_hat2 = np.linalg.inv(X_with_intercept2.T @ X_with_intercept2) * sigma_squared_hat2
u_inter[2] = intercept2 + 1.96 * (var_beta_hat2[0, 0] ** 0.5)
u_coeff[2] = coeff2 + 1.96 * (var_beta_hat2[1, 1] ** 0.5)
l_inter[2] = intercept2 - 1.96 * (var_beta_hat2[0, 0] ** 0.5)
l_coeff[2] = coeff2 - 1.96 * (var_beta_hat2[1, 1] ** 0.5)

coeff3 = coefs[3]
intercept3 = inter[3]
N3 = len(X_fold3[['GAA']])
p3 = 2
X_with_intercept3 = np.empty(shape = (N3, p3), dtype = np.float)
X_with_intercept3[:, 0] = 1
X_with_intercept3[:, 1 : p3] = X_fold3[['GAA']].values
y_hat3 = lin_reg3.predict(X_fold3[['GAA']])
residuals3 = y_fold3['Sv%'].values - y_hat3
residual_sum_of_squares3 = residuals3.T @ residuals3
sigma_squared_hat3 = residual_sum_of_squares3 / (N3 - p3)
var_beta_hat3 = np.linalg.inv(X_with_intercept3.T @ X_with_intercept3) * sigma_squared_hat3
u_inter[3] = intercept3 + 1.96 * (var_beta_hat3[0, 0] ** 0.5)
u_coeff[3] = coeff3 + 1.96 * (var_beta_hat3[1, 1] ** 0.5)
l_inter[3] = intercept3 - 1.96 * (var_beta_hat3[0, 0] ** 0.5)
l_coeff[3] = coeff3 - 1.96 * (var_beta_hat3[1, 1] ** 0.5)

coeff4 = coefs[4]
intercept4 = inter[4]
N4 = len(X_fold4[['GAA']])
p4 = 2
X_with_intercept4 = np.empty(shape = (N4, p4), dtype = np.float)
X_with_intercept4[:, 0] = 1
X_with_intercept4[:, 1 : p4] = X_fold4[['GAA']].values
y_hat4 = lin_reg4.predict(X_fold4[['GAA']])
residuals4 = y_fold4['Sv%'].values - y_hat4
residual_sum_of_squares4 = residuals4.T @ residuals4
sigma_squared_hat4 = residual_sum_of_squares4 / (N4 - p4)
var_beta_hat4 = np.linalg.inv(X_with_intercept4.T @ X_with_intercept4) * sigma_squared_hat4
u_inter[4] = intercept4 + 1.96 * (var_beta_hat4[0, 0] ** 0.5)
u_coeff[4] = coeff4 + 1.96 * (var_beta_hat4[1, 1] ** 0.5)
l_inter[4] = intercept4 - 1.96 * (var_beta_hat4[0, 0] ** 0.5)
l_coeff[4] = coeff4 - 1.96 * (var_beta_hat4[1, 1] ** 0.5)

coeff5 = coefs[5]
intercept5 = inter[5]
N5 = len(X_fold5[['GAA']])
p5 = 2
X_with_intercept5 = np.empty(shape = (N5, p5), dtype = np.float)
X_with_intercept5[:, 0] = 1
X_with_intercept5[:, 1 : p5] = X_fold5[['GAA']].values
y_hat5 = lin_reg5.predict(X_fold5[['GAA']])
residuals5 = y_fold5['Sv%'].values - y_hat5
residual_sum_of_squares5 = residuals5.T @ residuals5
sigma_squared_hat5 = residual_sum_of_squares5 / (N5 - p5)
var_beta_hat5 = np.linalg.inv(X_with_intercept5.T @ X_with_intercept5) * sigma_squared_hat5
u_inter[5] = intercept5 + 1.96 * (var_beta_hat5[0, 0] ** 0.5)
u_coeff[5] = coeff5 + 1.96 * (var_beta_hat5[1, 1] ** 0.5)
l_inter[5] = intercept5 - 1.96 * (var_beta_hat5[0, 0] ** 0.5)
l_coeff[5] = coeff5 - 1.96 * (var_beta_hat5[1, 1] ** 0.5)

coeff6 = coefs[6]
intercept6 = inter[6]
N6 = len(X_fold6[['GAA']])
p6 = 2
X_with_intercept6 = np.empty(shape = (N6, p6), dtype = np.float)
X_with_intercept6[:, 0] = 1
X_with_intercept6[:, 1 : p6] = X_fold6[['GAA']].values
y_hat6 = lin_reg6.predict(X_fold6[['GAA']])
residuals6 = y_fold6['Sv%'].values - y_hat6
residual_sum_of_squares6 = residuals6.T @ residuals6
sigma_squared_hat6 = residual_sum_of_squares6 / (N6 - p6)
var_beta_hat6 = np.linalg.inv(X_with_intercept6.T @ X_with_intercept6) * sigma_squared_hat6
u_inter[6] = intercept6 + 1.96 * (var_beta_hat6[0, 0] ** 0.5)
u_coeff[6] = coeff6 + 1.96 * (var_beta_hat6[1, 1] ** 0.5)
l_inter[6] = intercept6 - 1.96 * (var_beta_hat6[0, 0] ** 0.5)
l_coeff[6] = coeff6 - 1.96 * (var_beta_hat6[1, 1] ** 0.5)

coeff7 = coefs[7]
intercept7 = inter[7]
N7 = len(X_fold7[['GAA']])
p7 = 2
X_with_intercept7 = np.empty(shape = (N7, p7), dtype = np.float)
X_with_intercept7[:, 0] = 1
X_with_intercept7[:, 1 : p7] = X_fold7[['GAA']].values
y_hat7 = lin_reg7.predict(X_fold7[['GAA']])
residuals7 = y_fold7['Sv%'].values - y_hat7
residual_sum_of_squares7 = residuals7.T @ residuals7
sigma_squared_hat7 = residual_sum_of_squares7 / (N7 - p7)
var_beta_hat7 = np.linalg.inv(X_with_intercept7.T @ X_with_intercept7) * sigma_squared_hat7
u_inter[7] = intercept7 + 1.96 * (var_beta_hat7[0, 0] ** 0.5)
u_coeff[7] = coeff7 + 1.96 * (var_beta_hat7[1, 1] ** 0.5)
l_inter[7] = intercept7 - 1.96 * (var_beta_hat7[0, 0] ** 0.5)
l_coeff[7] = coeff7 - 1.96 * (var_beta_hat7[1, 1] ** 0.5)

coeff8 = coefs[8]
intercept8 = inter[8]
N8 = len(X_fold8[['GAA']])
p8 = 2
X_with_intercept8 = np.empty(shape = (N8, p8), dtype = np.float)
X_with_intercept8[:, 0] = 1
X_with_intercept8[:, 1 : p8] = X_fold8[['GAA']].values
y_hat8 = lin_reg8.predict(X_fold8[['GAA']])
residuals8 = y_fold8['Sv%'].values - y_hat8
residual_sum_of_squares8 = residuals8.T @ residuals8
sigma_squared_hat8 = residual_sum_of_squares8 / (N8 - p8)
var_beta_hat8 = np.linalg.inv(X_with_intercept8.T @ X_with_intercept8) * sigma_squared_hat8
u_inter[8] = intercept8 + 1.96 * (var_beta_hat8[0, 0] ** 0.5)
u_coeff[8] = coeff8 + 1.96 * (var_beta_hat8[1, 1] ** 0.5)
l_inter[8] = intercept8 - 1.96 * (var_beta_hat8[0, 0] ** 0.5)
l_coeff[8] = coeff8 - 1.96 * (var_beta_hat8[1, 1] ** 0.5)

coeff9 = coefs[9]
intercept9 = inter[9]
N9 = len(X_fold9[['GAA']])
p9 = 2
X_with_intercept9 = np.empty(shape = (N9, p9), dtype = np.float)
X_with_intercept9[:, 0] = 1
X_with_intercept9[:, 1 : p9] = X_fold9[['GAA']].values
y_hat9 = lin_reg9.predict(X_fold9[['GAA']])
residuals9 = y_fold9['Sv%'].values - y_hat9
residual_sum_of_squares9 = residuals9.T @ residuals9
sigma_squared_hat9 = residual_sum_of_squares9 / (N9 - p9)
var_beta_hat9 = np.linalg.inv(X_with_intercept9.T @ X_with_intercept9) * sigma_squared_hat9
u_inter[9] = intercept9 + 1.96 * (var_beta_hat9[0, 0] ** 0.5)
u_coeff[9] = coeff9 + 1.96 * (var_beta_hat9[1, 1] ** 0.5)
l_inter[9] = intercept9 - 1.96 * (var_beta_hat9[0, 0] ** 0.5)
l_coeff[9] = coeff9 - 1.96 * (var_beta_hat9[1, 1] ** 0.5)

coeff10 = coefs[10]
intercept10 = inter[10]
N10 = len(X_fold10[['GAA']])
p10 = 2
X_with_intercept10 = np.empty(shape = (N10, p10), dtype = np.float)
X_with_intercept10[:, 0] = 1
X_with_intercept10[:, 1 : p10] = X_fold10[['GAA']].values
y_hat10 = lin_reg10.predict(X_fold10[['GAA']])
residuals10 = y_fold10['Sv%'].values - y_hat10
residual_sum_of_squares10 = residuals10.T @ residuals10
sigma_squared_hat10 = residual_sum_of_squares10 / (N10 - p10)
var_beta_hat10 = np.linalg.inv(X_with_intercept10.T @ X_with_intercept10) * sigma_squared_hat10
u_inter[10] = intercept10 + 1.96 * (var_beta_hat10[0, 0] ** 0.5)
u_coeff[10] = coeff10 + 1.96 * (var_beta_hat10[1, 1] ** 0.5)
l_inter[10] = intercept10 - 1.96 * (var_beta_hat10[0, 0] ** 0.5)
l_coeff[10] = coeff10 - 1.96 * (var_beta_hat10[1, 1] ** 0.5)

coeff11 = coefs[11]
intercept11 = inter[11]
N11 = len(X_fold11[['GAA']])
p11 = 2
X_with_intercept11 = np.empty(shape = (N11, p11), dtype = np.float)
X_with_intercept11[:, 0] = 1
X_with_intercept11[:, 1 : p11] = X_fold11[['GAA']].values
y_hat11 = lin_reg11.predict(X_fold11[['GAA']])
residuals11 = y_fold11['Sv%'].values - y_hat11
residual_sum_of_squares11 = residuals11.T @ residuals11
sigma_squared_hat11 = residual_sum_of_squares11 / (N11 - p11)
var_beta_hat11 = np.linalg.inv(X_with_intercept11.T @ X_with_intercept11) * sigma_squared_hat11
u_inter[11] = intercept11 + 1.96 * (var_beta_hat11[0, 0] ** 0.5)
u_coeff[11] = coeff11 + 1.96 * (var_beta_hat11[1, 1] ** 0.5)
l_inter[11] = intercept11 - 1.96 * (var_beta_hat11[0, 0] ** 0.5)
l_coeff[11] = coeff11 - 1.96 * (var_beta_hat11[1, 1] ** 0.5)

coeff12 = coefs[12]
intercept12 = inter[12]
N12 = len(X_fold12[['GAA']])
p12 = 2
X_with_intercept12 = np.empty(shape = (N12, p12), dtype = np.float)
X_with_intercept12[:, 0] = 1
X_with_intercept12[:, 1 : p12] = X_fold12[['GAA']].values
y_hat12 = lin_reg12.predict(X_fold12[['GAA']])
residuals12 = y_fold12['Sv%'].values - y_hat12
residual_sum_of_squares12 = residuals12.T @ residuals12
sigma_squared_hat12 = residual_sum_of_squares12 / (N12 - p12)
var_beta_hat12 = np.linalg.inv(X_with_intercept12.T @ X_with_intercept12) * sigma_squared_hat12
u_inter[12] = intercept12 + 1.96 * (var_beta_hat12[0, 0] ** 0.5)
u_coeff[12] = coeff12 + 1.96 * (var_beta_hat12[1, 1] ** 0.5)
l_inter[12] = intercept12 - 1.96 * (var_beta_hat12[0, 0] ** 0.5)
l_coeff[12] = coeff12 - 1.96 * (var_beta_hat12[1, 1] ** 0.5)

coeff13 = coefs[13]
intercept13 = inter[13]
N13 = len(X_fold13[['GAA']])
p13 = 2
X_with_intercept13 = np.empty(shape = (N13, p13), dtype = np.float)
X_with_intercept13[:, 0] = 1
X_with_intercept13[:, 1 : p13] = X_fold13[['GAA']].values
y_hat13 = lin_reg13.predict(X_fold13[['GAA']])
residuals13 = y_fold13['Sv%'].values - y_hat13
residual_sum_of_squares13 = residuals13.T @ residuals13
sigma_squared_hat13 = residual_sum_of_squares13 / (N13 - p13)
var_beta_hat13 = np.linalg.inv(X_with_intercept13.T @ X_with_intercept13) * sigma_squared_hat13
u_inter[13] = intercept13 + 1.96 * (var_beta_hat13[0, 0] ** 0.5)
u_coeff[13] = coeff13 + 1.96 * (var_beta_hat13[1, 1] ** 0.5)
l_inter[13] = intercept13 - 1.96 * (var_beta_hat13[0, 0] ** 0.5)
l_coeff[13] = coeff13 - 1.96 * (var_beta_hat13[1, 1] ** 0.5)

coeff14 = coefs[14]
intercept14 = inter[14]
N14 = len(X_fold14[['GAA']])
p14 = 2
X_with_intercept14 = np.empty(shape = (N14, p14), dtype = np.float)
X_with_intercept14[:, 0] = 1
X_with_intercept14[:, 1 : p14] = X_fold14[['GAA']].values
y_hat14 = lin_reg14.predict(X_fold14[['GAA']])
residuals14 = y_fold14['Sv%'].values - y_hat14
residual_sum_of_squares14 = residuals14.T @ residuals14
sigma_squared_hat14 = residual_sum_of_squares14 / (N14 - p14)
var_beta_hat14 = np.linalg.inv(X_with_intercept14.T @ X_with_intercept14) * sigma_squared_hat14
u_inter[14] = intercept14 + 1.96 * (var_beta_hat14[0, 0] ** 0.5)
u_coeff[14] = coeff14 + 1.96 * (var_beta_hat14[1, 1] ** 0.5)
l_inter[14] = intercept14 - 1.96 * (var_beta_hat14[0, 0] ** 0.5)
l_coeff[14] = coeff14 - 1.96 * (var_beta_hat14[1, 1] ** 0.5)

coeff15 = coefs[15]
intercept15 = inter[15]
N15 = len(X_fold15[['GAA']])
p15 = 2
X_with_intercept15 = np.empty(shape = (N15, p15), dtype = np.float)
X_with_intercept15[:, 0] = 1
X_with_intercept15[:, 1 : p15] = X_fold15[['GAA']].values
y_hat15 = lin_reg15.predict(X_fold15[['GAA']])
residuals15 = y_fold15['Sv%'].values - y_hat15
residual_sum_of_squares15 = residuals15.T @ residuals15
sigma_squared_hat15 = residual_sum_of_squares15 / (N15 - p15)
var_beta_hat15 = np.linalg.inv(X_with_intercept15.T @ X_with_intercept15) * sigma_squared_hat15
u_inter[15] = intercept15 + 1.96 * (var_beta_hat15[0, 0] ** 0.5)
u_coeff[15] = coeff15 + 1.96 * (var_beta_hat15[1, 1] ** 0.5)
l_inter[15] = intercept15 - 1.96 * (var_beta_hat15[0, 0] ** 0.5)
l_coeff[15] = coeff15 - 1.96 * (var_beta_hat15[1, 1] ** 0.5)

coeff16 = coefs[16]
intercept16 = inter[16]
N16 = len(X_fold16[['GAA']])
p16 = 2
X_with_intercept16 = np.empty(shape = (N16, p16), dtype = np.float)
X_with_intercept16[:, 0] = 1
X_with_intercept16[:, 1 : p16] = X_fold16[['GAA']].values
y_hat16 = lin_reg16.predict(X_fold16[['GAA']])
residuals16 = y_fold16['Sv%'].values - y_hat16
residual_sum_of_squares16 = residuals16.T @ residuals16
sigma_squared_hat16 = residual_sum_of_squares16 / (N16 - p16)
var_beta_hat16 = np.linalg.inv(X_with_intercept16.T @ X_with_intercept16) * sigma_squared_hat16
u_inter[16] = intercept16 + 1.96 * (var_beta_hat16[0, 0] ** 0.5)
u_coeff[16] = coeff16 + 1.96 * (var_beta_hat16[1, 1] ** 0.5)
l_inter[16] = intercept16 - 1.96 * (var_beta_hat16[0, 0] ** 0.5)
l_coeff[16] = coeff16 - 1.96 * (var_beta_hat16[1, 1] ** 0.5)

coeff17 = coefs[17]
intercept17 = inter[17]
N17 = len(X_fold17[['GAA']])
p17 = 2
X_with_intercept17 = np.empty(shape = (N17, p17), dtype = np.float)
X_with_intercept17[:, 0] = 1
X_with_intercept17[:, 1 : p17] = X_fold17[['GAA']].values
y_hat17 = lin_reg17.predict(X_fold17[['GAA']])
residuals17 = y_fold17['Sv%'].values - y_hat17
residual_sum_of_squares17 = residuals17.T @ residuals17
sigma_squared_hat17 = residual_sum_of_squares17 / (N17 - p17)
var_beta_hat17 = np.linalg.inv(X_with_intercept17.T @ X_with_intercept17) * sigma_squared_hat17
u_inter[17] = intercept17 + 1.96 * (var_beta_hat17[0, 0] ** 0.5)
u_coeff[17] = coeff17 + 1.96 * (var_beta_hat17[1, 1] ** 0.5)
l_inter[17] = intercept17 - 1.96 * (var_beta_hat17[0, 0] ** 0.5)
l_coeff[17] = coeff17 - 1.96 * (var_beta_hat17[1, 1] ** 0.5)

coeff18 = coefs[18]
intercept18 = inter[18]
N18 = len(X_fold18[['GAA']])
p18 = 2
X_with_intercept18 = np.empty(shape = (N18, p18), dtype = np.float)
X_with_intercept18[:, 0] = 1
X_with_intercept18[:, 1 : p18] = X_fold18[['GAA']].values
y_hat18 = lin_reg18.predict(X_fold18[['GAA']])
residuals18 = y_fold18['Sv%'].values - y_hat18
residual_sum_of_squares18 = residuals18.T @ residuals18
sigma_squared_hat18 = residual_sum_of_squares18 / (N18 - p18)
var_beta_hat18 = np.linalg.inv(X_with_intercept18.T @ X_with_intercept18) * sigma_squared_hat18
u_inter[18] = intercept18 + 1.96 * (var_beta_hat18[0, 0] ** 0.5)
u_coeff[18] = coeff18 + 1.96 * (var_beta_hat18[1, 1] ** 0.5)
l_inter[18] = intercept18 - 1.96 * (var_beta_hat18[0, 0] ** 0.5)
l_coeff[18] = coeff18 - 1.96 * (var_beta_hat18[1, 1] ** 0.5)

coeff19 = coefs[19]
intercept19 = inter[19]
N19 = len(X_fold19[['GAA']])
p19 = 2
X_with_intercept19 = np.empty(shape = (N19, p19), dtype = np.float)
X_with_intercept19[:, 0] = 1
X_with_intercept19[:, 1 : p19] = X_fold19[['GAA']].values
y_hat19 = lin_reg19.predict(X_fold19[['GAA']])
residuals19 = y_fold19['Sv%'].values - y_hat19
residual_sum_of_squares19 = residuals19.T @ residuals19
sigma_squared_hat19 = residual_sum_of_squares19 / (N19 - p19)
var_beta_hat19 = np.linalg.inv(X_with_intercept19.T @ X_with_intercept19) * sigma_squared_hat19
u_inter[19] = intercept19 + 1.96 * (var_beta_hat19[0, 0] ** 0.5)
u_coeff[19] = coeff19 + 1.96 * (var_beta_hat19[1, 1] ** 0.5)
l_inter[19] = intercept19 - 1.96 * (var_beta_hat19[0, 0] ** 0.5)
l_coeff[19] = coeff19 - 1.96 * (var_beta_hat19[1, 1] ** 0.5)

coeff20 = coefs[20]
intercept20 = inter[20]
N20 = len(X_fold20[['GAA']])
p20 = 2
X_with_intercept20 = np.empty(shape = (N20, p20), dtype = np.float)
X_with_intercept20[:, 0] = 1
X_with_intercept20[:, 1 : p20] = X_fold20[['GAA']].values
y_hat20 = lin_reg20.predict(X_fold20[['GAA']])
residuals20 = y_fold20['Sv%'].values - y_hat20
residual_sum_of_squares20 = residuals20.T @ residuals20
sigma_squared_hat20 = residual_sum_of_squares20 / (N20 - p20)
var_beta_hat20 = np.linalg.inv(X_with_intercept20.T @ X_with_intercept20) * sigma_squared_hat20
u_inter[20] = intercept20 + 1.96 * (var_beta_hat20[0, 0] ** 0.5)
u_coeff[20] = coeff20 + 1.96 * (var_beta_hat20[1, 1] ** 0.5)
l_inter[20] = intercept20 - 1.96 * (var_beta_hat20[0, 0] ** 0.5)
l_coeff[20] = coeff20 - 1.96 * (var_beta_hat20[1, 1] ** 0.5)

coeff21 = coefs[21]
intercept21 = inter[21]
N21 = len(X_fold21[['GAA']])
p21 = 2
X_with_intercept21 = np.empty(shape = (N21, p21), dtype = np.float)
X_with_intercept21[:, 0] = 1
X_with_intercept21[:, 1 : p21] = X_fold21[['GAA']].values
y_hat21 = lin_reg21.predict(X_fold21[['GAA']])
residuals21 = y_fold21['Sv%'].values - y_hat21
residual_sum_of_squares21 = residuals21.T @ residuals21
sigma_squared_hat21 = residual_sum_of_squares21 / (N21 - p21)
var_beta_hat21 = np.linalg.inv(X_with_intercept21.T @ X_with_intercept21) * sigma_squared_hat21
u_inter[21] = intercept21 + 1.96 * (var_beta_hat21[0, 0] ** 0.5)
u_coeff[21] = coeff21 + 1.96 * (var_beta_hat21[1, 1] ** 0.5)
l_inter[21] = intercept21 - 1.96 * (var_beta_hat21[0, 0] ** 0.5)
l_coeff[21] = coeff21 - 1.96 * (var_beta_hat21[1, 1] ** 0.5)

coeff22 = coefs[22]
intercept22 = inter[22]
N22 = len(X_fold22[['GAA']])
p22 = 2
X_with_intercept22 = np.empty(shape = (N22, p22), dtype = np.float)
X_with_intercept22[:, 0] = 1
X_with_intercept22[:, 1 : p22] = X_fold22[['GAA']].values
y_hat22 = lin_reg22.predict(X_fold22[['GAA']])
residuals22 = y_fold22['Sv%'].values - y_hat22
residual_sum_of_squares22 = residuals22.T @ residuals22
sigma_squared_hat22 = residual_sum_of_squares22 / (N22 - p22)
var_beta_hat22 = np.linalg.inv(X_with_intercept22.T @ X_with_intercept22) * sigma_squared_hat22
u_inter[22] = intercept22 + 1.96 * (var_beta_hat22[0, 0] ** 0.5)
u_coeff[22] = coeff22 + 1.96 * (var_beta_hat22[1, 1] ** 0.5)
l_inter[22] = intercept22 - 1.96 * (var_beta_hat22[0, 0] ** 0.5)
l_coeff[22] = coeff22 - 1.96 * (var_beta_hat22[1, 1] ** 0.5)

coeff23 = coefs[23]
intercept23 = inter[23]
N23 = len(X_fold23[['GAA']])
p23 = 2
X_with_intercept23 = np.empty(shape = (N23, p23), dtype = np.float)
X_with_intercept23[:, 0] = 1
X_with_intercept23[:, 1 : p23] = X_fold23[['GAA']].values
y_hat23 = lin_reg23.predict(X_fold23[['GAA']])
residuals23 = y_fold23['Sv%'].values - y_hat23
residual_sum_of_squares23 = residuals23.T @ residuals23
sigma_squared_hat23 = residual_sum_of_squares23 / (N23 - p23)
var_beta_hat23 = np.linalg.inv(X_with_intercept23.T @ X_with_intercept23) * sigma_squared_hat23
u_inter[23] = intercept23 + 1.96 * (var_beta_hat23[0, 0] ** 0.5)
u_coeff[23] = coeff23 + 1.96 * (var_beta_hat23[1, 1] ** 0.5)
l_inter[23] = intercept23 - 1.96 * (var_beta_hat23[0, 0] ** 0.5)
l_coeff[23] = coeff23 - 1.96 * (var_beta_hat23[1, 1] ** 0.5)

coeff24 = coefs[24]
intercept24 = inter[24]
N24 = len(X_fold24[['GAA']])
p24 = 2
X_with_intercept24 = np.empty(shape = (N24, p24), dtype = np.float)
X_with_intercept24[:, 0] = 1
X_with_intercept24[:, 1 : p24] = X_fold24[['GAA']].values
y_hat24 = lin_reg24.predict(X_fold24[['GAA']])
residuals24 = y_fold24['Sv%'].values - y_hat24
residual_sum_of_squares24 = residuals24.T @ residuals24
sigma_squared_hat24 = residual_sum_of_squares24 / (N24 - p24)
var_beta_hat24 = np.linalg.inv(X_with_intercept24.T @ X_with_intercept24) * sigma_squared_hat24
u_inter[24] = intercept24 + 1.96 * (var_beta_hat24[0, 0] ** 0.5)
u_coeff[24] = coeff24 + 1.96 * (var_beta_hat24[1, 1] ** 0.5)
l_inter[24] = intercept24 - 1.96 * (var_beta_hat24[0, 0] ** 0.5)
l_coeff[24] = coeff24 - 1.96 * (var_beta_hat24[1, 1] ** 0.5)

coeff25 = coefs[25]
intercept25 = inter[25]
N25 = len(X_fold25[['GAA']])
p25 = 2
X_with_intercept25 = np.empty(shape = (N25, p25), dtype = np.float)
X_with_intercept25[:, 0] = 1
X_with_intercept25[:, 1 : p25] = X_fold25[['GAA']].values
y_hat25 = lin_reg25.predict(X_fold25[['GAA']])
residuals25 = y_fold25['Sv%'].values - y_hat25
residual_sum_of_squares25 = residuals25.T @ residuals25
sigma_squared_hat25 = residual_sum_of_squares25 / (N25 - p25)
var_beta_hat25 = np.linalg.inv(X_with_intercept25.T @ X_with_intercept25) * sigma_squared_hat25
u_inter[25] = intercept25 + 1.96 * (var_beta_hat25[0, 0] ** 0.5)
u_coeff[25] = coeff25 + 1.96 * (var_beta_hat25[1, 1] ** 0.5)
l_inter[25] = intercept25 - 1.96 * (var_beta_hat25[0, 0] ** 0.5)
l_coeff[25] = coeff25 - 1.96 * (var_beta_hat25[1, 1] ** 0.5)

coeff26 = coefs[26]
intercept26 = inter[26]
N26 = len(X_fold26[['GAA']])
p26 = 2
X_with_intercept26 = np.empty(shape = (N26, p26), dtype = np.float)
X_with_intercept26[:, 0] = 1
X_with_intercept26[:, 1 : p26] = X_fold26[['GAA']].values
y_hat26 = lin_reg26.predict(X_fold26[['GAA']])
residuals26 = y_fold26['Sv%'].values - y_hat26
residual_sum_of_squares26 = residuals26.T @ residuals26
sigma_squared_hat26 = residual_sum_of_squares26 / (N26 - p26)
var_beta_hat26 = np.linalg.inv(X_with_intercept26.T @ X_with_intercept26) * sigma_squared_hat26
u_inter[26] = intercept26 + 1.96 * (var_beta_hat26[0, 0] ** 0.5)
u_coeff[26] = coeff26 + 1.96 * (var_beta_hat26[1, 1] ** 0.5)
l_inter[26] = intercept26 - 1.96 * (var_beta_hat26[0, 0] ** 0.5)
l_coeff[26] = coeff26 - 1.96 * (var_beta_hat26[1, 1] ** 0.5)

coeff27 = coefs[27]
intercept27 = inter[27]
N27 = len(X_fold27[['GAA']])
p27 = 2
X_with_intercept27 = np.empty(shape = (N27, p27), dtype = np.float)
X_with_intercept27[:, 0] = 1
X_with_intercept27[:, 1 : p27] = X_fold27[['GAA']].values
y_hat27 = lin_reg27.predict(X_fold27[['GAA']])
residuals27 = y_fold27['Sv%'].values - y_hat27
residual_sum_of_squares27 = residuals27.T @ residuals27
sigma_squared_hat27 = residual_sum_of_squares27 / (N27 - p27)
var_beta_hat27 = np.linalg.inv(X_with_intercept27.T @ X_with_intercept27) * sigma_squared_hat27
u_inter[27] = intercept27 + 1.96 * (var_beta_hat27[0, 0] ** 0.5)
u_coeff[27] = coeff27 + 1.96 * (var_beta_hat27[1, 1] ** 0.5)
l_inter[27] = intercept27 - 1.96 * (var_beta_hat27[0, 0] ** 0.5)
l_coeff[27] = coeff27 - 1.96 * (var_beta_hat27[1, 1] ** 0.5)

coeff28 = coefs[28]
intercept28 = inter[28]
N28 = len(X_fold28[['GAA']])
p28 = 2
X_with_intercept28 = np.empty(shape = (N28, p28), dtype = np.float)
X_with_intercept28[:, 0] = 1
X_with_intercept28[:, 1 : p28] = X_fold28[['GAA']].values
y_hat28 = lin_reg28.predict(X_fold28[['GAA']])
residuals28 = y_fold28['Sv%'].values - y_hat28
residual_sum_of_squares28 = residuals28.T @ residuals28
sigma_squared_hat28 = residual_sum_of_squares28 / (N28 - p28)
var_beta_hat28 = np.linalg.inv(X_with_intercept28.T @ X_with_intercept28) * sigma_squared_hat28
u_inter[28] = intercept28 + 1.96 * (var_beta_hat28[0, 0] ** 0.5)
u_coeff[28] = coeff28 + 1.96 * (var_beta_hat28[1, 1] ** 0.5)
l_inter[28] = intercept28 - 1.96 * (var_beta_hat28[0, 0] ** 0.5)
l_coeff[28] = coeff28 - 1.96 * (var_beta_hat28[1, 1] ** 0.5)

coeff29 = coefs[29]
intercept29 = inter[29]
N29 = len(X_fold29[['GAA']])
p29 = 2
X_with_intercept29 = np.empty(shape = (N29, p29), dtype = np.float)
X_with_intercept29[:, 0] = 1
X_with_intercept29[:, 1 : p29] = X_fold29[['GAA']].values
y_hat29 = lin_reg29.predict(X_fold29[['GAA']])
residuals29 = y_fold29['Sv%'].values - y_hat29
residual_sum_of_squares29 = residuals29.T @ residuals29
sigma_squared_hat29 = residual_sum_of_squares29 / (N29 - p29)
var_beta_hat29 = np.linalg.inv(X_with_intercept29.T @ X_with_intercept29) * sigma_squared_hat29
u_inter[29] = intercept29 + 1.96 * (var_beta_hat29[0, 0] ** 0.5)
u_coeff[29] = coeff29 + 1.96 * (var_beta_hat29[1, 1] ** 0.5)
l_inter[29] = intercept29 - 1.96 * (var_beta_hat29[0, 0] ** 0.5)
l_coeff[29] = coeff29 - 1.96 * (var_beta_hat29[1, 1] ** 0.5)

coeff30 = coefs[30]
intercept30 = inter[30]
N30 = len(X_fold30[['GAA']])
p30 = 2
X_with_intercept30 = np.empty(shape = (N30, p30), dtype = np.float)
X_with_intercept30[:, 0] = 1
X_with_intercept30[:, 1 : p30] = X_fold30[['GAA']].values
y_hat30 = lin_reg30.predict(X_fold30[['GAA']])
residuals30 = y_fold30['Sv%'].values - y_hat30
residual_sum_of_squares30 = residuals30.T @ residuals30
sigma_squared_hat30 = residual_sum_of_squares30 / (N30 - p30)
var_beta_hat30 = np.linalg.inv(X_with_intercept30.T @ X_with_intercept30) * sigma_squared_hat30
u_inter[30] = intercept30 + 1.96 * (var_beta_hat30[0, 0] ** 0.5)
u_coeff[30] = coeff30 + 1.96 * (var_beta_hat30[1, 1] ** 0.5)
l_inter[30] = intercept30 - 1.96 * (var_beta_hat30[0, 0] ** 0.5)
l_coeff[30] = coeff30 - 1.96 * (var_beta_hat30[1, 1] ** 0.5)

coeff31 = coefs[31]
intercept31 = inter[31]
N31 = len(X_fold31[['GAA']])
p31 = 2
X_with_intercept31 = np.empty(shape = (N31, p31), dtype = np.float)
X_with_intercept31[:, 0] = 1
X_with_intercept31[:, 1 : p31] = X_fold31[['GAA']].values
y_hat31 = lin_reg31.predict(X_fold31[['GAA']])
residuals31 = y_fold31['Sv%'].values - y_hat31
residual_sum_of_squares31 = residuals31.T @ residuals31
sigma_squared_hat31 = residual_sum_of_squares31 / (N31 - p31)
var_beta_hat31 = np.linalg.inv(X_with_intercept31.T @ X_with_intercept31) * sigma_squared_hat31
u_inter[31] = intercept31 + 1.96 * (var_beta_hat31[0, 0] ** 0.5)
u_coeff[31] = coeff31 + 1.96 * (var_beta_hat31[1, 1] ** 0.5)
l_inter[31] = intercept31 - 1.96 * (var_beta_hat31[0, 0] ** 0.5)
l_coeff[31] = coeff31 - 1.96 * (var_beta_hat31[1, 1] ** 0.5)

coeff32 = coefs[32]
intercept32 = inter[32]
N32 = len(X_fold32[['GAA']])
p32 = 2
X_with_intercept32 = np.empty(shape = (N32, p32), dtype = np.float)
X_with_intercept32[:, 0] = 1
X_with_intercept32[:, 1 : p32] = X_fold32[['GAA']].values
y_hat32 = lin_reg32.predict(X_fold32[['GAA']])
residuals32 = y_fold32['Sv%'].values - y_hat32
residual_sum_of_squares32 = residuals32.T @ residuals32
sigma_squared_hat32 = residual_sum_of_squares32 / (N32 - p32)
var_beta_hat32 = np.linalg.inv(X_with_intercept32.T @ X_with_intercept32) * sigma_squared_hat32
u_inter[32] = intercept32 + 1.96 * (var_beta_hat32[0, 0] ** 0.5)
u_coeff[32] = coeff32 + 1.96 * (var_beta_hat32[1, 1] ** 0.5)
l_inter[32] = intercept32 - 1.96 * (var_beta_hat32[0, 0] ** 0.5)
l_coeff[32] = coeff32 - 1.96 * (var_beta_hat32[1, 1] ** 0.5)

coeff33 = coefs[33]
intercept33 = inter[33]
N33 = len(X_fold33[['GAA']])
p33 = 2
X_with_intercept33 = np.empty(shape = (N33, p33), dtype = np.float)
X_with_intercept33[:, 0] = 1
X_with_intercept33[:, 1 : p33] = X_fold33[['GAA']].values
y_hat33 = lin_reg33.predict(X_fold33[['GAA']])
residuals33 = y_fold33['Sv%'].values - y_hat33
residual_sum_of_squares33 = residuals33.T @ residuals33
sigma_squared_hat33 = residual_sum_of_squares33 / (N33 - p33)
var_beta_hat33 = np.linalg.inv(X_with_intercept33.T @ X_with_intercept33) * sigma_squared_hat33
u_inter[33] = intercept33 + 1.96 * (var_beta_hat33[0, 0] ** 0.5)
u_coeff[33] = coeff33 + 1.96 * (var_beta_hat33[1, 1] ** 0.5)
l_inter[33] = intercept33 - 1.96 * (var_beta_hat33[0, 0] ** 0.5)
l_coeff[33] = coeff33 - 1.96 * (var_beta_hat33[1, 1] ** 0.5)

coeff34 = coefs[34]
intercept34 = inter[34]
N34 = len(X_fold34[['GAA']])
p34 = 2
X_with_intercept34 = np.empty(shape = (N34, p34), dtype = np.float)
X_with_intercept34[:, 0] = 1
X_with_intercept34[:, 1 : p34] = X_fold34[['GAA']].values
y_hat34 = lin_reg34.predict(X_fold34[['GAA']])
residuals34 = y_fold34['Sv%'].values - y_hat34
residual_sum_of_squares34 = residuals34.T @ residuals34
sigma_squared_hat34 = residual_sum_of_squares34 / (N34 - p34)
var_beta_hat34 = np.linalg.inv(X_with_intercept34.T @ X_with_intercept34) * sigma_squared_hat34
u_inter[34] = intercept34 + 1.96 * (var_beta_hat34[0, 0] ** 0.5)
u_coeff[34] = coeff34 + 1.96 * (var_beta_hat34[1, 1] ** 0.5)
l_inter[34] = intercept34 - 1.96 * (var_beta_hat34[0, 0] ** 0.5)
l_coeff[34] = coeff34 - 1.96 * (var_beta_hat34[1, 1] ** 0.5)

coeff35 = coefs[35]
intercept35 = inter[35]
N35 = len(X_fold35[['GAA']])
p35 = 2
X_with_intercept35 = np.empty(shape = (N35, p35), dtype = np.float)
X_with_intercept35[:, 0] = 1
X_with_intercept35[:, 1 : p35] = X_fold35[['GAA']].values
y_hat35 = lin_reg35.predict(X_fold35[['GAA']])
residuals35 = y_fold35['Sv%'].values - y_hat35
residual_sum_of_squares35 = residuals35.T @ residuals35
sigma_squared_hat35 = residual_sum_of_squares35 / (N35 - p35)
var_beta_hat35 = np.linalg.inv(X_with_intercept35.T @ X_with_intercept35) * sigma_squared_hat35
u_inter[35] = intercept35 + 1.96 * (var_beta_hat35[0, 0] ** 0.5)
u_coeff[35] = coeff35 + 1.96 * (var_beta_hat35[1, 1] ** 0.5)
l_inter[35] = intercept35 - 1.96 * (var_beta_hat35[0, 0] ** 0.5)
l_coeff[35] = coeff35 - 1.96 * (var_beta_hat35[1, 1] ** 0.5)

coeff36 = coefs[36]
intercept36 = inter[36]
N36 = len(X_fold36[['GAA']])
p36 = 2
X_with_intercept36 = np.empty(shape = (N36, p36), dtype = np.float)
X_with_intercept36[:, 0] = 1
X_with_intercept36[:, 1 : p36] = X_fold36[['GAA']].values
y_hat36 = lin_reg36.predict(X_fold36[['GAA']])
residuals36 = y_fold36['Sv%'].values - y_hat36
residual_sum_of_squares36 = residuals36.T @ residuals36
sigma_squared_hat36 = residual_sum_of_squares36 / (N36 - p36)
var_beta_hat36 = np.linalg.inv(X_with_intercept36.T @ X_with_intercept36) * sigma_squared_hat36
u_inter[36] = intercept36 + 1.96 * (var_beta_hat36[0, 0] ** 0.5)
u_coeff[36] = coeff36 + 1.96 * (var_beta_hat36[1, 1] ** 0.5)
l_inter[36] = intercept36 - 1.96 * (var_beta_hat36[0, 0] ** 0.5)
l_coeff[36] = coeff36 - 1.96 * (var_beta_hat36[1, 1] ** 0.5)

coeff37 = coefs[37]
intercept37 = inter[37]
N37 = len(X_fold37[['GAA']])
p37 = 2
X_with_intercept37 = np.empty(shape = (N37, p37), dtype = np.float)
X_with_intercept37[:, 0] = 1
X_with_intercept37[:, 1 : p37] = X_fold37[['GAA']].values
y_hat37 = lin_reg37.predict(X_fold37[['GAA']])
residuals37 = y_fold37['Sv%'].values - y_hat37
residual_sum_of_squares37 = residuals37.T @ residuals37
sigma_squared_hat37 = residual_sum_of_squares37 / (N37 - p37)
var_beta_hat37 = np.linalg.inv(X_with_intercept37.T @ X_with_intercept37) * sigma_squared_hat37
u_inter[37] = intercept37 + 1.96 * (var_beta_hat37[0, 0] ** 0.5)
u_coeff[37] = coeff37 + 1.96 * (var_beta_hat37[1, 1] ** 0.5)
l_inter[37] = intercept37 - 1.96 * (var_beta_hat37[0, 0] ** 0.5)
l_coeff[37] = coeff37 - 1.96 * (var_beta_hat37[1, 1] ** 0.5)

coeff38 = coefs[38]
intercept38 = inter[38]
N38 = len(X_fold38[['GAA']])
p38 = 2
X_with_intercept38 = np.empty(shape = (N38, p38), dtype = np.float)
X_with_intercept38[:, 0] = 1
X_with_intercept38[:, 1 : p38] = X_fold38[['GAA']].values
y_hat38 = lin_reg38.predict(X_fold38[['GAA']])
residuals38 = y_fold38['Sv%'].values - y_hat38
residual_sum_of_squares38 = residuals38.T @ residuals38
sigma_squared_hat38 = residual_sum_of_squares38 / (N38 - p38)
var_beta_hat38 = np.linalg.inv(X_with_intercept38.T @ X_with_intercept38) * sigma_squared_hat38
u_inter[38] = intercept38 + 1.96 * (var_beta_hat38[0, 0] ** 0.5)
u_coeff[38] = coeff38 + 1.96 * (var_beta_hat38[1, 1] ** 0.5)
l_inter[38] = intercept38 - 1.96 * (var_beta_hat38[0, 0] ** 0.5)
l_coeff[38] = coeff38 - 1.96 * (var_beta_hat38[1, 1] ** 0.5)

coeff39 = coefs[39]
intercept39 = inter[39]
N39 = len(X_fold39[['GAA']])
p39 = 2
X_with_intercept39 = np.empty(shape = (N39, p39), dtype = np.float)
X_with_intercept39[:, 0] = 1
X_with_intercept39[:, 1 : p39] = X_fold39[['GAA']].values
y_hat39 = lin_reg39.predict(X_fold39[['GAA']])
residuals39 = y_fold39['Sv%'].values - y_hat39
residual_sum_of_squares39 = residuals39.T @ residuals39
sigma_squared_hat39 = residual_sum_of_squares39 / (N39 - p39)
var_beta_hat39 = np.linalg.inv(X_with_intercept39.T @ X_with_intercept39) * sigma_squared_hat39
u_inter[39] = intercept39 + 1.96 * (var_beta_hat39[0, 0] ** 0.5)
u_coeff[39] = coeff39 + 1.96 * (var_beta_hat39[1, 1] ** 0.5)
l_inter[39] = intercept39 - 1.96 * (var_beta_hat39[0, 0] ** 0.5)
l_coeff[39] = coeff39 - 1.96 * (var_beta_hat39[1, 1] ** 0.5)

coeff40 = coefs[40]
intercept40 = inter[40]
N40 = len(X_fold40[['GAA']])
p40 = 2
X_with_intercept40 = np.empty(shape = (N40, p40), dtype = np.float)
X_with_intercept40[:, 0] = 1
X_with_intercept40[:, 1 : p40] = X_fold40[['GAA']].values
y_hat40 = lin_reg40.predict(X_fold40[['GAA']])
residuals40 = y_fold40['Sv%'].values - y_hat40
residual_sum_of_squares40 = residuals40.T @ residuals40
sigma_squared_hat40 = residual_sum_of_squares40 / (N40 - p40)
var_beta_hat40 = np.linalg.inv(X_with_intercept40.T @ X_with_intercept40) * sigma_squared_hat40
u_inter[40] = intercept40 + 1.96 * (var_beta_hat40[0, 0] ** 0.5)
u_coeff[40] = coeff40 + 1.96 * (var_beta_hat40[1, 1] ** 0.5)
l_inter[40] = intercept40 - 1.96 * (var_beta_hat40[0, 0] ** 0.5)
l_coeff[40] = coeff40 - 1.96 * (var_beta_hat40[1, 1] ** 0.5)

coeff41 = coefs[41]
intercept41 = inter[41]
N41 = len(X_fold41[['GAA']])
p41 = 2
X_with_intercept41 = np.empty(shape = (N41, p41), dtype = np.float)
X_with_intercept41[:, 0] = 1
X_with_intercept41[:, 1 : p41] = X_fold41[['GAA']].values
y_hat41 = lin_reg41.predict(X_fold41[['GAA']])
residuals41 = y_fold41['Sv%'].values - y_hat41
residual_sum_of_squares41 = residuals41.T @ residuals41
sigma_squared_hat41 = residual_sum_of_squares41 / (N41 - p41)
var_beta_hat41 = np.linalg.inv(X_with_intercept41.T @ X_with_intercept41) * sigma_squared_hat41
u_inter[41] = intercept41 + 1.96 * (var_beta_hat41[0, 0] ** 0.5)
u_coeff[41] = coeff41 + 1.96 * (var_beta_hat41[1, 1] ** 0.5)
l_inter[41] = intercept41 - 1.96 * (var_beta_hat41[0, 0] ** 0.5)
l_coeff[41] = coeff41 - 1.96 * (var_beta_hat41[1, 1] ** 0.5)

coeff42 = coefs[42]
intercept42 = inter[42]
N42 = len(X_fold42[['GAA']])
p42 = 2
X_with_intercept42 = np.empty(shape = (N42, p42), dtype = np.float)
X_with_intercept42[:, 0] = 1
X_with_intercept42[:, 1 : p42] = X_fold42[['GAA']].values
y_hat42 = lin_reg42.predict(X_fold42[['GAA']])
residuals42 = y_fold42['Sv%'].values - y_hat42
residual_sum_of_squares42 = residuals42.T @ residuals42
sigma_squared_hat42 = residual_sum_of_squares42 / (N42 - p42)
var_beta_hat42 = np.linalg.inv(X_with_intercept42.T @ X_with_intercept42) * sigma_squared_hat42
u_inter[42] = intercept42 + 1.96 * (var_beta_hat42[0, 0] ** 0.5)
u_coeff[42] = coeff42 + 1.96 * (var_beta_hat42[1, 1] ** 0.5)
l_inter[42] = intercept42 - 1.96 * (var_beta_hat42[0, 0] ** 0.5)
l_coeff[42] = coeff42 - 1.96 * (var_beta_hat42[1, 1] ** 0.5)

coeff43 = coefs[43]
intercept43 = inter[43]
N43 = len(X_fold43[['GAA']])
p43 = 2
X_with_intercept43 = np.empty(shape = (N43, p43), dtype = np.float)
X_with_intercept43[:, 0] = 1
X_with_intercept43[:, 1 : p43] = X_fold43[['GAA']].values
y_hat43 = lin_reg43.predict(X_fold43[['GAA']])
residuals43 = y_fold43['Sv%'].values - y_hat43
residual_sum_of_squares43 = residuals43.T @ residuals43
sigma_squared_hat43 = residual_sum_of_squares43 / (N43 - p43)
var_beta_hat43 = np.linalg.inv(X_with_intercept43.T @ X_with_intercept43) * sigma_squared_hat43
u_inter[43] = intercept43 + 1.96 * (var_beta_hat43[0, 0] ** 0.5)
u_coeff[43] = coeff43 + 1.96 * (var_beta_hat43[1, 1] ** 0.5)
l_inter[43] = intercept43 - 1.96 * (var_beta_hat43[0, 0] ** 0.5)
l_coeff[43] = coeff43 - 1.96 * (var_beta_hat43[1, 1] ** 0.5)

coeff44 = coefs[44]
intercept44 = inter[44]
N44 = len(X_fold44[['GAA']])
p44 = 2
X_with_intercept44 = np.empty(shape = (N44, p44), dtype = np.float)
X_with_intercept44[:, 0] = 1
X_with_intercept44[:, 1 : p44] = X_fold44[['GAA']].values
y_hat44 = lin_reg44.predict(X_fold44[['GAA']])
residuals44 = y_fold44['Sv%'].values - y_hat44
residual_sum_of_squares44 = residuals44.T @ residuals44
sigma_squared_hat44 = residual_sum_of_squares44 / (N44 - p44)
var_beta_hat44 = np.linalg.inv(X_with_intercept44.T @ X_with_intercept44) * sigma_squared_hat44
u_inter[44] = intercept44 + 1.96 * (var_beta_hat44[0, 0] ** 0.5)
u_coeff[44] = coeff44 + 1.96 * (var_beta_hat44[1, 1] ** 0.5)
l_inter[44] = intercept44 - 1.96 * (var_beta_hat44[0, 0] ** 0.5)
l_coeff[44] = coeff44 - 1.96 * (var_beta_hat44[1, 1] ** 0.5)

coeff45 = coefs[45]
intercept45 = inter[45]
N45 = len(X_fold45[['GAA']])
p45 = 2
X_with_intercept45 = np.empty(shape = (N45, p45), dtype = np.float)
X_with_intercept45[:, 0] = 1
X_with_intercept45[:, 1 : p45] = X_fold45[['GAA']].values
y_hat45 = lin_reg45.predict(X_fold45[['GAA']])
residuals45 = y_fold45['Sv%'].values - y_hat45
residual_sum_of_squares45 = residuals45.T @ residuals45
sigma_squared_hat45 = residual_sum_of_squares45 / (N45 - p45)
var_beta_hat45 = np.linalg.inv(X_with_intercept45.T @ X_with_intercept45) * sigma_squared_hat45
u_inter[45] = intercept45 + 1.96 * (var_beta_hat45[0, 0] ** 0.5)
u_coeff[45] = coeff45 + 1.96 * (var_beta_hat45[1, 1] ** 0.5)
l_inter[45] = intercept45 - 1.96 * (var_beta_hat45[0, 0] ** 0.5)
l_coeff[45] = coeff45 - 1.96 * (var_beta_hat45[1, 1] ** 0.5)

coeff46 = coefs[46]
intercept46 = inter[46]
N46 = len(X_fold46[['GAA']])
p46 = 2
X_with_intercept46 = np.empty(shape = (N46, p46), dtype = np.float)
X_with_intercept46[:, 0] = 1
X_with_intercept46[:, 1 : p46] = X_fold46[['GAA']].values
y_hat46 = lin_reg46.predict(X_fold46[['GAA']])
residuals46 = y_fold46['Sv%'].values - y_hat46
residual_sum_of_squares46 = residuals46.T @ residuals46
sigma_squared_hat46 = residual_sum_of_squares46 / (N46 - p46)
var_beta_hat46 = np.linalg.inv(X_with_intercept46.T @ X_with_intercept46) * sigma_squared_hat46
u_inter[46] = intercept46 + 1.96 * (var_beta_hat46[0, 0] ** 0.5)
u_coeff[46] = coeff46 + 1.96 * (var_beta_hat46[1, 1] ** 0.5)
l_inter[46] = intercept46 - 1.96 * (var_beta_hat46[0, 0] ** 0.5)
l_coeff[46] = coeff46 - 1.96 * (var_beta_hat46[1, 1] ** 0.5)

coeff47 = coefs[47]
intercept47 = inter[47]
N47 = len(X_fold47[['GAA']])
p47 = 2
X_with_intercept47 = np.empty(shape = (N47, p47), dtype = np.float)
X_with_intercept47[:, 0] = 1
X_with_intercept47[:, 1 : p47] = X_fold47[['GAA']].values
y_hat47 = lin_reg47.predict(X_fold47[['GAA']])
residuals47 = y_fold47['Sv%'].values - y_hat47
residual_sum_of_squares47 = residuals47.T @ residuals47
sigma_squared_hat47 = residual_sum_of_squares47 / (N47 - p47)
var_beta_hat47 = np.linalg.inv(X_with_intercept47.T @ X_with_intercept47) * sigma_squared_hat47
u_inter[47] = intercept47 + 1.96 * (var_beta_hat47[0, 0] ** 0.5)
u_coeff[47] = coeff47 + 1.96 * (var_beta_hat47[1, 1] ** 0.5)
l_inter[47] = intercept47 - 1.96 * (var_beta_hat47[0, 0] ** 0.5)
l_coeff[47] = coeff47 - 1.96 * (var_beta_hat47[1, 1] ** 0.5)

coeff48 = coefs[48]
intercept48 = inter[48]
N48 = len(X_fold48[['GAA']])
p48 = 2
X_with_intercept48 = np.empty(shape = (N48, p48), dtype = np.float)
X_with_intercept48[:, 0] = 1
X_with_intercept48[:, 1 : p48] = X_fold48[['GAA']].values
y_hat48 = lin_reg48.predict(X_fold48[['GAA']])
residuals48 = y_fold48['Sv%'].values - y_hat48
residual_sum_of_squares48 = residuals48.T @ residuals48
sigma_squared_hat48 = residual_sum_of_squares48 / (N48 - p48)
var_beta_hat48 = np.linalg.inv(X_with_intercept48.T @ X_with_intercept48) * sigma_squared_hat48
u_inter[48] = intercept48 + 1.96 * (var_beta_hat48[0, 0] ** 0.5)
u_coeff[48] = coeff48 + 1.96 * (var_beta_hat48[1, 1] ** 0.5)
l_inter[48] = intercept48 - 1.96 * (var_beta_hat48[0, 0] ** 0.5)
l_coeff[48] = coeff48 - 1.96 * (var_beta_hat48[1, 1] ** 0.5)

coeff49 = coefs[49]
intercept49 = inter[49]
N49 = len(X_fold49[['GAA']])
p49 = 2
X_with_intercept49 = np.empty(shape = (N49, p49), dtype = np.float)
X_with_intercept49[:, 0] = 1
X_with_intercept49[:, 1 : p49] = X_fold49[['GAA']].values
y_hat49 = lin_reg49.predict(X_fold49[['GAA']])
residuals49 = y_fold49['Sv%'].values - y_hat49
residual_sum_of_squares49 = residuals49.T @ residuals49
sigma_squared_hat49 = residual_sum_of_squares49 / (N49 - p49)
var_beta_hat49 = np.linalg.inv(X_with_intercept49.T @ X_with_intercept49) * sigma_squared_hat49
u_inter[49] = intercept49 + 1.96 * (var_beta_hat49[0, 0] ** 0.5)
u_coeff[49] = coeff49 + 1.96 * (var_beta_hat49[1, 1] ** 0.5)
l_inter[49] = intercept49 - 1.96 * (var_beta_hat49[0, 0] ** 0.5)
l_coeff[49] = coeff49 - 1.96 * (var_beta_hat49[1, 1] ** 0.5)

# %%
#Aggregate k=50 Folds
coeff = sum(coefs)/len(coefs)
intercept = sum(inter)/len(inter)

u_coeff = sum(u_coeff)/len(u_coeff)
u_intercept = sum(u_inter)/len(u_inter)

l_coeff = sum(l_coeff)/len(l_coeff)
l_intercept = sum(l_inter)/len(l_inter)

# %% [markdown]
# ## Sample For Goaltender w/ GAA = 2.50

# %%
#Upper 95% Confidence Inteval
u_intercept + u_coeff * 2.5
# Out:
# array([0.91530818])

# %%
#Prediction
intercept + coeff * 2.5
# Out:
# array([0.91227549])

# %%
#Lower 95% Confidence Interval
l_intercept + coeff * 2.5
# Out:
# array([0.91060853])
