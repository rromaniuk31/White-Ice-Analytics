# %% [markdown]
# # Import Things

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get Data

# %%
df1918 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1918Goalies.csv")
df1919 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1919Goalies.csv")
df1920 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1920Goalies.csv")
df1921 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1921Goalies.csv")
df1922 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1922Goalies.csv")
df1923 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1923Goalies.csv")
df1924 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1924Goalies.csv")
df1925 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1925Goalies.csv")
df1926 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1926Goalies.csv")
df1927 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1927Goalies.csv")
df1928 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1928Goalies.csv")
df1929 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1929Goalies.csv")
df1930 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1930Goalies.csv")
df1931 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1931Goalies.csv")
df1932 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1932Goalies.csv")
df1933 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1933Goalies.csv")
df1934 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1934Goalies.csv")
df1935 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1935Goalies.csv")
df1936 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1936Goalies.csv")
df1937 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1937Goalies.csv")
df1938 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1938Goalies.csv")
df1939 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1939Goalies.csv")
df1940 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1940Goalies.csv")
df1941 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1941Goalies.csv")
df1942 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1942Goalies.csv")
df1943 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1943Goalies.csv")
df1944 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1944Goalies.csv")
df1945 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1945Goalies.csv")
df1946 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1946Goalies.csv")
df1947 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1947Goalies.csv")
df1948 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1948Goalies.csv")
df1949 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1949Goalies.csv")
df1950 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1950Goalies.csv")
df1951 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1951Goalies.csv")
df1952 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1952Goalies.csv")
df1953 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1953Goalies.csv")
df1954 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1954Goalies.csv")
df1955 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1955Goalies.csv")
df1956 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1956Goalies.csv")
df1957 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1957Goalies.csv")
df1958 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1958Goalies.csv")
df1959 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1959Goalies.csv")
df1960 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1960Goalies.csv")
df1961 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1961Goalies.csv")
df1962 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1962Goalies.csv")
df1963 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1963Goalies.csv")
df1964 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1964Goalies.csv")
df1965 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1965Goalies.csv")
df1966 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1966Goalies.csv")
df1967 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1967Goalies.csv")
df1968 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1968Goalies.csv")
df1969 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1969Goalies.csv")
df1970 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1970Goalies.csv")
df1971 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1971Goalies.csv")
df1972 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1972Goalies.csv")
df1973 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1973Goalies.csv")
df1974 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1974Goalies.csv")
df1975 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1975Goalies.csv")
df1976 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1976Goalies.csv")
df1977 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1977Goalies.csv")
df1978 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1978Goalies.csv")
df1979 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1979Goalies.csv")
df1980 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1980Goalies.csv")
df1981 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1981Goalies.csv")
df1982 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1982Goalies.csv")
df1983 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1983Goalies.csv")
df1984 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1984Goalies.csv")
df1985 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1985Goalies.csv")
df1986 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1986Goalies.csv")
df1987 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1987Goalies.csv")
df1988 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1988Goalies.csv")
df1989 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1989Goalies.csv")
df1990 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1990Goalies.csv")
df1991 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1991Goalies.csv")
df1992 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1992Goalies.csv")
df1993 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1993Goalies.csv")
df1994 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1994Goalies.csv")
df1995 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1995Goalies.csv")
df1996 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1996Goalies.csv")
df1997 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1997Goalies.csv")
df1998 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1998Goalies.csv")
df1999 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\1999Goalies.csv")
df2000 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2000Goalies.csv")
df2001 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2001Goalies.csv")
df2002 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2002Goalies.csv")
df2003 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2003Goalies.csv")
df2004 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2004Goalies.csv")
df2006 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2006Goalies.csv")
df2007 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2007Goalies.csv")
df2008 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2008Goalies.csv")
df2009 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2009Goalies.csv")
df2010 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2010Goalies.csv")
df2011 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2011Goalies.csv")
df2012 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2012Goalies.csv")
df2013 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2013Goalies.csv")
df2014 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2014Goalies.csv")
df2015 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2015Goalies.csv")
df2016 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2016Goalies.csv")
df2017 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2017Goalies.csv")
df2018 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2018Goalies.csv")
df2019 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2019Goalies.csv")
df2020 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2020Goalies.csv")
df2021 = pd.read_csv("D:\\White Ice Analytics\\Historical Goalie Stats\\Regular Season\\2021Goalies.csv")

# %%
df_list = [df1918, df1919, df1920, df1921, df1922, df1923, df1924, df1925, df1926, df1927, df1928, df1929, df1930, df1931, df1932, df1933, df1934, df1935, df1936, df1937, df1938, df1939, df1940, df1941, df1942, df1943, df1944, df1945, df1946, df1947, df1948, df1949, df1950, df1951, df1952, df1953, df1954, df1955, df1956, df1957, df1958, df1959, df1960, df1961, df1962, df1963, df1964, df1965, df1966, df1967, df1968, df1969, df1970, df1971, df1972, df1973, df1974, df1975, df1976, df1977, df1978, df1979, df1980, df1981, df1982, df1983, df1984, df1985, df1986, df1987, df1988, df1989, df1990, df1991, df1992, df1993, df1994, df1995, df1996, df1997, df1998, df1999, df2000, df2001, df2002, df2003, df2004, df2006, df2007, df2008, df2009, df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021]
df_list_no18 = df_list[1:]

# %% [markdown]
# # Fill Blanks w/ Zeros

# %%
for df in df_list:
    for i in range(0, len(df)):
        if df['T'][i] == '--':
            df['T'][i] = 0
            
        if df['OT'][i] == '--':
            df['OT'][i] = 0

        if df['SA'][i] == '--':
            df['SA'][i] = 0

        if df['Svs'][i] == '--':
            df['Svs'][i] = 0

        if df['Sv%'][i] == '--':
            df['Sv%'][i] = 0
# Out:
# <ipython-input-4-7d66b00f57db>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OT'][i] = 0
# <ipython-input-4-7d66b00f57db>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SA'][i] = 0
# <ipython-input-4-7d66b00f57db>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Svs'][i] = 0
# <ipython-input-4-7d66b00f57db>:16: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Create Actual GP Column

# %%
for i in range(0, len(df)):
    df1918[['Minutes','Seconds','Milli']] = df1918['TOI'].str.split(':', expand = True)
    df1918['Actual GP'] = ''
    for i in range(0, len(df1918)):
        if ',' in df1918['Minutes'][i]:
            df1918[['Min1', 'Min2']] = df1918['Minutes'].str.split(',', expand = True)
            df1918['Minutes'][i] = df1918['Min1'][i] + df1918['Min2'][i]
            df1918 = df1918.drop(columns = ['Min1', 'Min2', 'Milli'])

    df1918['Minutes'] = pd.to_numeric(df1918['Minutes'])
    df1918['Seconds'] = pd.to_numeric(df1918['Seconds'])
    
for i in range(0, len(df1918)):
    df1918['TOI'][i] = df1918['Minutes'][i] + (df1918['Seconds'][i]/60)
    df1918['Actual GP'][i] = df1918['TOI'][i]/60
    
df1918 = df1918.drop(columns = ['Minutes', 'Seconds', 'Milli'])
# Out:
# <ipython-input-5-ce32d7a96275>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1918['TOI'][i] = df1918['Minutes'][i] + (df1918['Seconds'][i]/60)
# <ipython-input-5-ce32d7a96275>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1918['Actual GP'][i] = df1918['TOI'][i]/60

# %%
for df in df_list_no18:
    df[['Minutes', 'Seconds']] = df['TOI'].str.split(':', expand = True)
    df['Actual GP'] = ''
    for i in range(0, len(df)):
        if ',' in df['Minutes'][i]:
            df[['Min1', 'Min2']] = df['Minutes'].str.split(',', expand = True)
            df['Minutes'][i] = df['Min1'][i] + df['Min2'][i]
            df = df.drop(columns = ['Min1', 'Min2'])
            
    df['Minutes'] = pd.to_numeric(df['Minutes'])
    df['Seconds'] = pd.to_numeric(df['Seconds'])
    
    for i in range(0, len(df)):
        df['TOI'][i] = df['Minutes'][i] + (df['Seconds'][i]/60)
        df['Actual GP'][i] = df['TOI'][i]/60
        
    df = df.drop(columns = ['Minutes', 'Seconds'])
    
for i in range(0, len(df1990)):
    df1990[['Minutes','Seconds']] = df1990['TOI'].str.split(':', expand = True)
    df1990['Actual GP'] = ''
    for i in range(0, len(df1990)):
        if ',' in df1990['Minutes'][i]:
            df1990[['Min1', 'Min2']] = df1990['Minutes'].str.split(',', expand = True)
            df1990['Minutes'][i] = df1990['Min1'][i] + df1990['Min2'][i]
            df1990 = df1990.drop(columns = ['Min1', 'Min2'])

    df1990['Minutes'] = pd.to_numeric(df1990['Minutes'])
    df1990['Seconds'] = pd.to_numeric(df1990['Seconds'])
    
for i in range(0, len(df1990)):
    df1990['TOI'][i] = df1990['Minutes'][i] + (df1990['Seconds'][i]/60)
    df1990['Actual GP'][i] = df1990['TOI'][i]/60
    
df1990 = df1990.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1991)):
    df1991[['Minutes','Seconds']] = df1991['TOI'].str.split(':', expand = True)
    df1991['Actual GP'] = ''
    for i in range(0, len(df1991)):
        if ',' in df1991['Minutes'][i]:
            df1991[['Min1', 'Min2']] = df1991['Minutes'].str.split(',', expand = True)
            df1991['Minutes'][i] = df1991['Min1'][i] + df1991['Min2'][i]
            df1991 = df1991.drop(columns = ['Min1', 'Min2'])

    df1991['Minutes'] = pd.to_numeric(df1991['Minutes'])
    df1991['Seconds'] = pd.to_numeric(df1991['Seconds'])
    
for i in range(0, len(df1991)):
    df1991['TOI'][i] = df1991['Minutes'][i] + (df1991['Seconds'][i]/60)
    df1991['Actual GP'][i] = df1991['TOI'][i]/60
    
df1991 = df1991.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1992)):
    df1992[['Minutes','Seconds']] = df1992['TOI'].str.split(':', expand = True)
    df1992['Actual GP'] = ''
    for i in range(0, len(df1992)):
        if ',' in df1992['Minutes'][i]:
            df1992[['Min1', 'Min2']] = df1992['Minutes'].str.split(',', expand = True)
            df1992['Minutes'][i] = df1992['Min1'][i] + df1992['Min2'][i]
            df1992 = df1992.drop(columns = ['Min1', 'Min2'])

    df1992['Minutes'] = pd.to_numeric(df1992['Minutes'])
    df1992['Seconds'] = pd.to_numeric(df1992['Seconds'])
    
for i in range(0, len(df1992)):
    df1992['TOI'][i] = df1992['Minutes'][i] + (df1992['Seconds'][i]/60)
    df1992['Actual GP'][i] = df1992['TOI'][i]/60
    
df1992 = df1992.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1993)):
    df1993[['Minutes','Seconds']] = df1993['TOI'].str.split(':', expand = True)
    df1993['Actual GP'] = ''
    for i in range(0, len(df1993)):
        if ',' in df1993['Minutes'][i]:
            df1993[['Min1', 'Min2']] = df1993['Minutes'].str.split(',', expand = True)
            df1993['Minutes'][i] = df1993['Min1'][i] + df1993['Min2'][i]
            df1993 = df1993.drop(columns = ['Min1', 'Min2'])

    df1993['Minutes'] = pd.to_numeric(df1993['Minutes'])
    df1993['Seconds'] = pd.to_numeric(df1993['Seconds'])
    
for i in range(0, len(df1993)):
    df1993['TOI'][i] = df1993['Minutes'][i] + (df1993['Seconds'][i]/60)
    df1993['Actual GP'][i] = df1993['TOI'][i]/60
    
df1993 = df1993.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1994)):
    df1994[['Minutes','Seconds']] = df1994['TOI'].str.split(':', expand = True)
    df1994['Actual GP'] = ''
    for i in range(0, len(df1994)):
        if ',' in df1994['Minutes'][i]:
            df1994[['Min1', 'Min2']] = df1994['Minutes'].str.split(',', expand = True)
            df1994['Minutes'][i] = df1994['Min1'][i] + df1994['Min2'][i]
            df1994 = df1994.drop(columns = ['Min1', 'Min2'])

    df1994['Minutes'] = pd.to_numeric(df1994['Minutes'])
    df1994['Seconds'] = pd.to_numeric(df1994['Seconds'])
    
for i in range(0, len(df1994)):
    df1994['TOI'][i] = df1994['Minutes'][i] + (df1994['Seconds'][i]/60)
    df1994['Actual GP'][i] = df1994['TOI'][i]/60
    
df1994 = df1994.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1995)):
    df1995[['Minutes','Seconds']] = df1995['TOI'].str.split(':', expand = True)
    df1995['Actual GP'] = ''
    for i in range(0, len(df1995)):
        if ',' in df1995['Minutes'][i]:
            df1995[['Min1', 'Min2']] = df1995['Minutes'].str.split(',', expand = True)
            df1995['Minutes'][i] = df1995['Min1'][i] + df1995['Min2'][i]
            df1995 = df1995.drop(columns = ['Min1', 'Min2'])

    df1995['Minutes'] = pd.to_numeric(df1995['Minutes'])
    df1995['Seconds'] = pd.to_numeric(df1995['Seconds'])
    
for i in range(0, len(df1995)):
    df1995['TOI'][i] = df1995['Minutes'][i] + (df1995['Seconds'][i]/60)
    df1995['Actual GP'][i] = df1995['TOI'][i]/60
    
df1995 = df1995.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1996)):
    df1996[['Minutes','Seconds']] = df1996['TOI'].str.split(':', expand = True)
    df1996['Actual GP'] = ''
    for i in range(0, len(df1996)):
        if ',' in df1996['Minutes'][i]:
            df1996[['Min1', 'Min2']] = df1996['Minutes'].str.split(',', expand = True)
            df1996['Minutes'][i] = df1996['Min1'][i] + df1996['Min2'][i]
            df1996 = df1996.drop(columns = ['Min1', 'Min2'])

    df1996['Minutes'] = pd.to_numeric(df1996['Minutes'])
    df1996['Seconds'] = pd.to_numeric(df1996['Seconds'])
    
for i in range(0, len(df1996)):
    df1996['TOI'][i] = df1996['Minutes'][i] + (df1996['Seconds'][i]/60)
    df1996['Actual GP'][i] = df1996['TOI'][i]/60
    
df1996 = df1996.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1997)):
    df1997[['Minutes','Seconds']] = df1997['TOI'].str.split(':', expand = True)
    df1997['Actual GP'] = ''
    for i in range(0, len(df1997)):
        if ',' in df1997['Minutes'][i]:
            df1997[['Min1', 'Min2']] = df1997['Minutes'].str.split(',', expand = True)
            df1997['Minutes'][i] = df1997['Min1'][i] + df1997['Min2'][i]
            df1997 = df1997.drop(columns = ['Min1', 'Min2'])

    df1997['Minutes'] = pd.to_numeric(df1997['Minutes'])
    df1997['Seconds'] = pd.to_numeric(df1997['Seconds'])
    
for i in range(0, len(df1997)):
    df1997['TOI'][i] = df1997['Minutes'][i] + (df1997['Seconds'][i]/60)
    df1997['Actual GP'][i] = df1997['TOI'][i]/60
    
df1997 = df1997.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1998)):
    df1998[['Minutes','Seconds']] = df1998['TOI'].str.split(':', expand = True)
    df1998['Actual GP'] = ''
    for i in range(0, len(df1998)):
        if ',' in df1998['Minutes'][i]:
            df1998[['Min1', 'Min2']] = df1998['Minutes'].str.split(',', expand = True)
            df1998['Minutes'][i] = df1998['Min1'][i] + df1998['Min2'][i]
            df1998 = df1998.drop(columns = ['Min1', 'Min2'])

    df1998['Minutes'] = pd.to_numeric(df1998['Minutes'])
    df1998['Seconds'] = pd.to_numeric(df1998['Seconds'])
    
for i in range(0, len(df1998)):
    df1998['TOI'][i] = df1998['Minutes'][i] + (df1998['Seconds'][i]/60)
    df1998['Actual GP'][i] = df1998['TOI'][i]/60
    
df1998 = df1998.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df1999)):
    df1999[['Minutes','Seconds']] = df1999['TOI'].str.split(':', expand = True)
    df1999['Actual GP'] = ''
    for i in range(0, len(df1999)):
        if ',' in df1999['Minutes'][i]:
            df1999[['Min1', 'Min2']] = df1999['Minutes'].str.split(',', expand = True)
            df1999['Minutes'][i] = df1999['Min1'][i] + df1999['Min2'][i]
            df1999 = df1999.drop(columns = ['Min1', 'Min2'])

    df1999['Minutes'] = pd.to_numeric(df1999['Minutes'])
    df1999['Seconds'] = pd.to_numeric(df1999['Seconds'])
    
for i in range(0, len(df1999)):
    df1999['TOI'][i] = df1999['Minutes'][i] + (df1999['Seconds'][i]/60)
    df1999['Actual GP'][i] = df1999['TOI'][i]/60
    
df1999 = df1999.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2000)):
    df2000[['Minutes','Seconds']] = df2000['TOI'].str.split(':', expand = True)
    df2000['Actual GP'] = ''
    for i in range(0, len(df2000)):
        if ',' in df2000['Minutes'][i]:
            df2000[['Min1', 'Min2']] = df2000['Minutes'].str.split(',', expand = True)
            df2000['Minutes'][i] = df2000['Min1'][i] + df2000['Min2'][i]
            df2000 = df2000.drop(columns = ['Min1', 'Min2'])

    df2000['Minutes'] = pd.to_numeric(df2000['Minutes'])
    df2000['Seconds'] = pd.to_numeric(df2000['Seconds'])
    
for i in range(0, len(df2000)):
    df2000['TOI'][i] = df2000['Minutes'][i] + (df2000['Seconds'][i]/60)
    df2000['Actual GP'][i] = df2000['TOI'][i]/60
    
df2000 = df2000.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2001)):
    df2001[['Minutes','Seconds']] = df2001['TOI'].str.split(':', expand = True)
    df2001['Actual GP'] = ''
    for i in range(0, len(df2001)):
        if ',' in df2001['Minutes'][i]:
            df2001[['Min1', 'Min2']] = df2001['Minutes'].str.split(',', expand = True)
            df2001['Minutes'][i] = df2001['Min1'][i] + df2001['Min2'][i]
            df2001 = df2001.drop(columns = ['Min1', 'Min2'])

    df2001['Minutes'] = pd.to_numeric(df2001['Minutes'])
    df2001['Seconds'] = pd.to_numeric(df2001['Seconds'])
    
for i in range(0, len(df2001)):
    df2001['TOI'][i] = df2001['Minutes'][i] + (df2001['Seconds'][i]/60)
    df2001['Actual GP'][i] = df2001['TOI'][i]/60
    
df2001 = df2001.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2002)):
    df2002[['Minutes','Seconds']] = df2002['TOI'].str.split(':', expand = True)
    df2002['Actual GP'] = ''
    for i in range(0, len(df2002)):
        if ',' in df2002['Minutes'][i]:
            df2002[['Min1', 'Min2']] = df2002['Minutes'].str.split(',', expand = True)
            df2002['Minutes'][i] = df2002['Min1'][i] + df2002['Min2'][i]
            df2002 = df2002.drop(columns = ['Min1', 'Min2'])

    df2002['Minutes'] = pd.to_numeric(df2002['Minutes'])
    df2002['Seconds'] = pd.to_numeric(df2002['Seconds'])
    
for i in range(0, len(df2002)):
    df2002['TOI'][i] = df2002['Minutes'][i] + (df2002['Seconds'][i]/60)
    df2002['Actual GP'][i] = df2002['TOI'][i]/60
    
df2002 = df2002.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2003)):
    df2003[['Minutes','Seconds']] = df2003['TOI'].str.split(':', expand = True)
    df2003['Actual GP'] = ''
    for i in range(0, len(df2003)):
        if ',' in df2003['Minutes'][i]:
            df2003[['Min1', 'Min2']] = df2003['Minutes'].str.split(',', expand = True)
            df2003['Minutes'][i] = df2003['Min1'][i] + df2003['Min2'][i]
            df2003 = df2003.drop(columns = ['Min1', 'Min2'])

    df2003['Minutes'] = pd.to_numeric(df2003['Minutes'])
    df2003['Seconds'] = pd.to_numeric(df2003['Seconds'])
    
for i in range(0, len(df2003)):
    df2003['TOI'][i] = df2003['Minutes'][i] + (df2003['Seconds'][i]/60)
    df2003['Actual GP'][i] = df2003['TOI'][i]/60
    
df2003 = df2003.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2004)):
    df2004[['Minutes','Seconds']] = df2004['TOI'].str.split(':', expand = True)
    df2004['Actual GP'] = ''
    for i in range(0, len(df2004)):
        if ',' in df2004['Minutes'][i]:
            df2004[['Min1', 'Min2']] = df2004['Minutes'].str.split(',', expand = True)
            df2004['Minutes'][i] = df2004['Min1'][i] + df2004['Min2'][i]
            df2004 = df2004.drop(columns = ['Min1', 'Min2'])

    df2004['Minutes'] = pd.to_numeric(df2004['Minutes'])
    df2004['Seconds'] = pd.to_numeric(df2004['Seconds'])
    
for i in range(0, len(df2004)):
    df2004['TOI'][i] = df2004['Minutes'][i] + (df2004['Seconds'][i]/60)
    df2004['Actual GP'][i] = df2004['TOI'][i]/60
    
df2004 = df2004.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2006)):
    df2006[['Minutes','Seconds']] = df2006['TOI'].str.split(':', expand = True)
    df2006['Actual GP'] = ''
    for i in range(0, len(df2006)):
        if ',' in df2006['Minutes'][i]:
            df2006[['Min1', 'Min2']] = df2006['Minutes'].str.split(',', expand = True)
            df2006['Minutes'][i] = df2006['Min1'][i] + df2006['Min2'][i]
            df2006 = df2006.drop(columns = ['Min1', 'Min2'])

    df2006['Minutes'] = pd.to_numeric(df2006['Minutes'])
    df2006['Seconds'] = pd.to_numeric(df2006['Seconds'])
    
for i in range(0, len(df2006)):
    df2006['TOI'][i] = df2006['Minutes'][i] + (df2006['Seconds'][i]/60)
    df2006['Actual GP'][i] = df2006['TOI'][i]/60
    
df2006 = df2006.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2007)):
    df2007[['Minutes','Seconds']] = df2007['TOI'].str.split(':', expand = True)
    df2007['Actual GP'] = ''
    for i in range(0, len(df2007)):
        if ',' in df2007['Minutes'][i]:
            df2007[['Min1', 'Min2']] = df2007['Minutes'].str.split(',', expand = True)
            df2007['Minutes'][i] = df2007['Min1'][i] + df2007['Min2'][i]
            df2007 = df2007.drop(columns = ['Min1', 'Min2'])

    df2007['Minutes'] = pd.to_numeric(df2007['Minutes'])
    df2007['Seconds'] = pd.to_numeric(df2007['Seconds'])
    
for i in range(0, len(df2007)):
    df2007['TOI'][i] = df2007['Minutes'][i] + (df2007['Seconds'][i]/60)
    df2007['Actual GP'][i] = df2007['TOI'][i]/60
    
df2007 = df2007.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2008)):
    df2008[['Minutes','Seconds']] = df2008['TOI'].str.split(':', expand = True)
    df2008['Actual GP'] = ''
    for i in range(0, len(df2008)):
        if ',' in df2008['Minutes'][i]:
            df2008[['Min1', 'Min2']] = df2008['Minutes'].str.split(',', expand = True)
            df2008['Minutes'][i] = df2008['Min1'][i] + df2008['Min2'][i]
            df2008 = df2008.drop(columns = ['Min1', 'Min2'])

    df2008['Minutes'] = pd.to_numeric(df2008['Minutes'])
    df2008['Seconds'] = pd.to_numeric(df2008['Seconds'])
    
for i in range(0, len(df2008)):
    df2008['TOI'][i] = df2008['Minutes'][i] + (df2008['Seconds'][i]/60)
    df2008['Actual GP'][i] = df2008['TOI'][i]/60
    
df2008 = df2008.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2009)):
    df2009[['Minutes','Seconds']] = df2009['TOI'].str.split(':', expand = True)
    df2009['Actual GP'] = ''
    for i in range(0, len(df2009)):
        if ',' in df2009['Minutes'][i]:
            df2009[['Min1', 'Min2']] = df2009['Minutes'].str.split(',', expand = True)
            df2009['Minutes'][i] = df2009['Min1'][i] + df2009['Min2'][i]
            df2009 = df2009.drop(columns = ['Min1', 'Min2'])

    df2009['Minutes'] = pd.to_numeric(df2009['Minutes'])
    df2009['Seconds'] = pd.to_numeric(df2009['Seconds'])
    
for i in range(0, len(df2009)):
    df2009['TOI'][i] = df2009['Minutes'][i] + (df2009['Seconds'][i]/60)
    df2009['Actual GP'][i] = df2009['TOI'][i]/60
    
df2009 = df2009.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2010)):
    df2010[['Minutes','Seconds']] = df2010['TOI'].str.split(':', expand = True)
    df2010['Actual GP'] = ''
    for i in range(0, len(df2010)):
        if ',' in df2010['Minutes'][i]:
            df2010[['Min1', 'Min2']] = df2010['Minutes'].str.split(',', expand = True)
            df2010['Minutes'][i] = df2010['Min1'][i] + df2010['Min2'][i]
            df2010 = df2010.drop(columns = ['Min1', 'Min2'])

    df2010['Minutes'] = pd.to_numeric(df2010['Minutes'])
    df2010['Seconds'] = pd.to_numeric(df2010['Seconds'])
    
for i in range(0, len(df2010)):
    df2010['TOI'][i] = df2010['Minutes'][i] + (df2010['Seconds'][i]/60)
    df2010['Actual GP'][i] = df2010['TOI'][i]/60
    
df2010 = df2010.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2011)):
    df2011[['Minutes','Seconds']] = df2011['TOI'].str.split(':', expand = True)
    df2011['Actual GP'] = ''
    for i in range(0, len(df2011)):
        if ',' in df2011['Minutes'][i]:
            df2011[['Min1', 'Min2']] = df2011['Minutes'].str.split(',', expand = True)
            df2011['Minutes'][i] = df2011['Min1'][i] + df2011['Min2'][i]
            df2011 = df2011.drop(columns = ['Min1', 'Min2'])

    df2011['Minutes'] = pd.to_numeric(df2011['Minutes'])
    df2011['Seconds'] = pd.to_numeric(df2011['Seconds'])
    
for i in range(0, len(df2011)):
    df2011['TOI'][i] = df2011['Minutes'][i] + (df2011['Seconds'][i]/60)
    df2011['Actual GP'][i] = df2011['TOI'][i]/60
    
df2011 = df2011.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2012)):
    df2012[['Minutes','Seconds']] = df2012['TOI'].str.split(':', expand = True)
    df2012['Actual GP'] = ''
    for i in range(0, len(df2012)):
        if ',' in df2012['Minutes'][i]:
            df2012[['Min1', 'Min2']] = df2012['Minutes'].str.split(',', expand = True)
            df2012['Minutes'][i] = df2012['Min1'][i] + df2012['Min2'][i]
            df2012 = df2012.drop(columns = ['Min1', 'Min2'])

    df2012['Minutes'] = pd.to_numeric(df2012['Minutes'])
    df2012['Seconds'] = pd.to_numeric(df2012['Seconds'])
    
for i in range(0, len(df2012)):
    df2012['TOI'][i] = df2012['Minutes'][i] + (df2012['Seconds'][i]/60)
    df2012['Actual GP'][i] = df2012['TOI'][i]/60
    
df2012 = df2012.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2013)):
    df2013[['Minutes','Seconds']] = df2013['TOI'].str.split(':', expand = True)
    df2013['Actual GP'] = ''
    for i in range(0, len(df2013)):
        if ',' in df2013['Minutes'][i]:
            df2013[['Min1', 'Min2']] = df2013['Minutes'].str.split(',', expand = True)
            df2013['Minutes'][i] = df2013['Min1'][i] + df2013['Min2'][i]
            df2013 = df2013.drop(columns = ['Min1', 'Min2'])

    df2013['Minutes'] = pd.to_numeric(df2013['Minutes'])
    df2013['Seconds'] = pd.to_numeric(df2013['Seconds'])
    
for i in range(0, len(df2013)):
    df2013['TOI'][i] = df2013['Minutes'][i] + (df2013['Seconds'][i]/60)
    df2013['Actual GP'][i] = df2013['TOI'][i]/60
    
df2013 = df2013.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2014)):
    df2014[['Minutes','Seconds']] = df2014['TOI'].str.split(':', expand = True)
    df2014['Actual GP'] = ''
    for i in range(0, len(df2014)):
        if ',' in df2014['Minutes'][i]:
            df2014[['Min1', 'Min2']] = df2014['Minutes'].str.split(',', expand = True)
            df2014['Minutes'][i] = df2014['Min1'][i] + df2014['Min2'][i]
            df2014 = df2014.drop(columns = ['Min1', 'Min2'])

    df2014['Minutes'] = pd.to_numeric(df2014['Minutes'])
    df2014['Seconds'] = pd.to_numeric(df2014['Seconds'])
    
for i in range(0, len(df2014)):
    df2014['TOI'][i] = df2014['Minutes'][i] + (df2014['Seconds'][i]/60)
    df2014['Actual GP'][i] = df2014['TOI'][i]/60
    
df2014 = df2014.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2015)):
    df2015[['Minutes','Seconds']] = df2015['TOI'].str.split(':', expand = True)
    df2015['Actual GP'] = ''
    for i in range(0, len(df2015)):
        if ',' in df2015['Minutes'][i]:
            df2015[['Min1', 'Min2']] = df2015['Minutes'].str.split(',', expand = True)
            df2015['Minutes'][i] = df2015['Min1'][i] + df2015['Min2'][i]
            df2015 = df2015.drop(columns = ['Min1', 'Min2'])

    df2015['Minutes'] = pd.to_numeric(df2015['Minutes'])
    df2015['Seconds'] = pd.to_numeric(df2015['Seconds'])
    
for i in range(0, len(df2015)):
    df2015['TOI'][i] = df2015['Minutes'][i] + (df2015['Seconds'][i]/60)
    df2015['Actual GP'][i] = df2015['TOI'][i]/60
    
df2015 = df2015.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2016)):
    df2016[['Minutes','Seconds']] = df2016['TOI'].str.split(':', expand = True)
    df2016['Actual GP'] = ''
    for i in range(0, len(df2016)):
        if ',' in df2016['Minutes'][i]:
            df2016[['Min1', 'Min2']] = df2016['Minutes'].str.split(',', expand = True)
            df2016['Minutes'][i] = df2016['Min1'][i] + df2016['Min2'][i]
            df2016 = df2016.drop(columns = ['Min1', 'Min2'])

    df2016['Minutes'] = pd.to_numeric(df2016['Minutes'])
    df2016['Seconds'] = pd.to_numeric(df2016['Seconds'])
    
for i in range(0, len(df2016)):
    df2016['TOI'][i] = df2016['Minutes'][i] + (df2016['Seconds'][i]/60)
    df2016['Actual GP'][i] = df2016['TOI'][i]/60
    
df2016 = df2016.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2017)):
    df2017[['Minutes','Seconds']] = df2017['TOI'].str.split(':', expand = True)
    df2017['Actual GP'] = ''
    for i in range(0, len(df2017)):
        if ',' in df2017['Minutes'][i]:
            df2017[['Min1', 'Min2']] = df2017['Minutes'].str.split(',', expand = True)
            df2017['Minutes'][i] = df2017['Min1'][i] + df2017['Min2'][i]
            df2017 = df2017.drop(columns = ['Min1', 'Min2'])

    df2017['Minutes'] = pd.to_numeric(df2017['Minutes'])
    df2017['Seconds'] = pd.to_numeric(df2017['Seconds'])
    
for i in range(0, len(df2017)):
    df2017['TOI'][i] = df2017['Minutes'][i] + (df2017['Seconds'][i]/60)
    df2017['Actual GP'][i] = df2017['TOI'][i]/60
    
df2017 = df2017.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2018)):
    df2018[['Minutes','Seconds']] = df2018['TOI'].str.split(':', expand = True)
    df2018['Actual GP'] = ''
    for i in range(0, len(df2018)):
        if ',' in df2018['Minutes'][i]:
            df2018[['Min1', 'Min2']] = df2018['Minutes'].str.split(',', expand = True)
            df2018['Minutes'][i] = df2018['Min1'][i] + df2018['Min2'][i]
            df2018 = df2018.drop(columns = ['Min1', 'Min2'])

    df2018['Minutes'] = pd.to_numeric(df2018['Minutes'])
    df2018['Seconds'] = pd.to_numeric(df2018['Seconds'])
    
for i in range(0, len(df2018)):
    df2018['TOI'][i] = df2018['Minutes'][i] + (df2018['Seconds'][i]/60)
    df2018['Actual GP'][i] = df2018['TOI'][i]/60
    
df2018 = df2018.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2019)):
    df2019[['Minutes','Seconds']] = df2019['TOI'].str.split(':', expand = True)
    df2019['Actual GP'] = ''
    for i in range(0, len(df2019)):
        if ',' in df2019['Minutes'][i]:
            df2019[['Min1', 'Min2']] = df2019['Minutes'].str.split(',', expand = True)
            df2019['Minutes'][i] = df2019['Min1'][i] + df2019['Min2'][i]
            df2019 = df2019.drop(columns = ['Min1', 'Min2'])

    df2019['Minutes'] = pd.to_numeric(df2019['Minutes'])
    df2019['Seconds'] = pd.to_numeric(df2019['Seconds'])
    
for i in range(0, len(df2019)):
    df2019['TOI'][i] = df2019['Minutes'][i] + (df2019['Seconds'][i]/60)
    df2019['Actual GP'][i] = df2019['TOI'][i]/60
    
df2019 = df2019.drop(columns = ['Minutes', 'Seconds'])

for i in range(0, len(df2020)):
    df2020[['Minutes','Seconds']] = df2020['TOI'].str.split(':', expand = True)
    df2020['Actual GP'] = ''
    for i in range(0, len(df2020)):
        if ',' in df2020['Minutes'][i]:
            df2020[['Min1', 'Min2']] = df2020['Minutes'].str.split(',', expand = True)
            df2020['Minutes'][i] = df2020['Min1'][i] + df2020['Min2'][i]
            df2020 = df2020.drop(columns = ['Min1', 'Min2'])

    df2020['Minutes'] = pd.to_numeric(df2020['Minutes'])
    df2020['Seconds'] = pd.to_numeric(df2020['Seconds'])
    
for i in range(0, len(df2020)):
    df2020['TOI'][i] = df2020['Minutes'][i] + (df2020['Seconds'][i]/60)
    df2020['Actual GP'][i] = df2020['TOI'][i]/60
    
df2020 = df2020.drop(columns = ['Minutes', 'Seconds'])
# Out:
# <ipython-input-6-d530fb9e909c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TOI'][i] = df['Minutes'][i] + (df['Seconds'][i]/60)
# <ipython-input-6-d530fb9e909c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Actual GP'][i] = df['TOI'][i]/60
# <ipython-input-6-d530fb9e909c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minutes'][i] = df['Min1'][i] + df['Min2'][i]
# ...

# %% [markdown]
# # Clean Up Shots Data

# %%
for i in range(0, len(df1956)):
    if ',' in df1956['SA'][i]:
        df1956[['SA1', 'SA2']] = df1956['SA'].str.split(',', expand = True)
        df1956['SA'][i] = df1956['SA1'][i] + df1956['SA2'][i]
        df1956 = df1956.drop(columns = ['SA1', 'SA2'])
    if ',' in df1956['Svs'][i]:
        df1956[['Svs1', 'Svs2']] = df1956['Svs'].str.split(',', expand = True)
        df1956['Svs'][i] = df1956['Svs1'][i] + df1956['Svs2'][i]
        df1956 = df1956.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1957)):
    if ',' in df1957['SA'][i]:
        df1957[['SA1', 'SA2']] = df1957['SA'].str.split(',', expand = True)
        df1957['SA'][i] = df1957['SA1'][i] + df1957['SA2'][i]
        df1957 = df1957.drop(columns = ['SA1', 'SA2'])
    if ',' in df1957['Svs'][i]:
        df1957[['Svs1', 'Svs2']] = df1957['Svs'].str.split(',', expand = True)
        df1957['Svs'][i] = df1957['Svs1'][i] + df1957['Svs2'][i]
        df1957 = df1957.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1958)):
    if ',' in df1958['SA'][i]:
        df1958[['SA1', 'SA2']] = df1958['SA'].str.split(',', expand = True)
        df1958['SA'][i] = df1958['SA1'][i] + df1958['SA2'][i]
        df1958 = df1958.drop(columns = ['SA1', 'SA2'])
    if ',' in df1958['Svs'][i]:
        df1958[['Svs1', 'Svs2']] = df1958['Svs'].str.split(',', expand = True)
        df1958['Svs'][i] = df1958['Svs1'][i] + df1958['Svs2'][i]
        df1958 = df1958.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1959)):
    if ',' in df1959['SA'][i]:
        df1959[['SA1', 'SA2']] = df1959['SA'].str.split(',', expand = True)
        df1959['SA'][i] = df1959['SA1'][i] + df1959['SA2'][i]
        df1959 = df1959.drop(columns = ['SA1', 'SA2'])
    if ',' in df1959['Svs'][i]:
        df1959[['Svs1', 'Svs2']] = df1959['Svs'].str.split(',', expand = True)
        df1959['Svs'][i] = df1959['Svs1'][i] + df1959['Svs2'][i]
        df1959 = df1959.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1960)):
    if ',' in df1960['SA'][i]:
        df1960[['SA1', 'SA2']] = df1960['SA'].str.split(',', expand = True)
        df1960['SA'][i] = df1960['SA1'][i] + df1960['SA2'][i]
        df1960 = df1960.drop(columns = ['SA1', 'SA2'])
    if ',' in df1960['Svs'][i]:
        df1960[['Svs1', 'Svs2']] = df1960['Svs'].str.split(',', expand = True)
        df1960['Svs'][i] = df1960['Svs1'][i] + df1960['Svs2'][i]
        df1960 = df1960.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1961)):
    if ',' in df1961['SA'][i]:
        df1961[['SA1', 'SA2']] = df1961['SA'].str.split(',', expand = True)
        df1961['SA'][i] = df1961['SA1'][i] + df1961['SA2'][i]
        df1961 = df1961.drop(columns = ['SA1', 'SA2'])
    if ',' in df1961['Svs'][i]:
        df1961[['Svs1', 'Svs2']] = df1961['Svs'].str.split(',', expand = True)
        df1961['Svs'][i] = df1961['Svs1'][i] + df1961['Svs2'][i]
        df1961 = df1961.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1962)):
    if ',' in df1962['SA'][i]:
        df1962[['SA1', 'SA2']] = df1962['SA'].str.split(',', expand = True)
        df1962['SA'][i] = df1962['SA1'][i] + df1962['SA2'][i]
        df1962 = df1962.drop(columns = ['SA1', 'SA2'])
    if ',' in df1962['Svs'][i]:
        df1962[['Svs1', 'Svs2']] = df1962['Svs'].str.split(',', expand = True)
        df1962['Svs'][i] = df1962['Svs1'][i] + df1962['Svs2'][i]
        df1962 = df1962.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1963)):
    if ',' in df1963['SA'][i]:
        df1963[['SA1', 'SA2']] = df1963['SA'].str.split(',', expand = True)
        df1963['SA'][i] = df1963['SA1'][i] + df1963['SA2'][i]
        df1963 = df1963.drop(columns = ['SA1', 'SA2'])
    if ',' in df1963['Svs'][i]:
        df1963[['Svs1', 'Svs2']] = df1963['Svs'].str.split(',', expand = True)
        df1963['Svs'][i] = df1963['Svs1'][i] + df1963['Svs2'][i]
        df1963 = df1963.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1964)):
    if ',' in df1964['SA'][i]:
        df1964[['SA1', 'SA2']] = df1964['SA'].str.split(',', expand = True)
        df1964['SA'][i] = df1964['SA1'][i] + df1964['SA2'][i]
        df1964 = df1964.drop(columns = ['SA1', 'SA2'])
    if ',' in df1964['Svs'][i]:
        df1964[['Svs1', 'Svs2']] = df1964['Svs'].str.split(',', expand = True)
        df1964['Svs'][i] = df1964['Svs1'][i] + df1964['Svs2'][i]
        df1964 = df1964.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1965)):
    if ',' in df1965['SA'][i]:
        df1965[['SA1', 'SA2']] = df1965['SA'].str.split(',', expand = True)
        df1965['SA'][i] = df1965['SA1'][i] + df1965['SA2'][i]
        df1965 = df1965.drop(columns = ['SA1', 'SA2'])
    if ',' in df1965['Svs'][i]:
        df1965[['Svs1', 'Svs2']] = df1965['Svs'].str.split(',', expand = True)
        df1965['Svs'][i] = df1965['Svs1'][i] + df1965['Svs2'][i]
        df1965 = df1965.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1966)):
    if ',' in df1966['SA'][i]:
        df1966[['SA1', 'SA2']] = df1966['SA'].str.split(',', expand = True)
        df1966['SA'][i] = df1966['SA1'][i] + df1966['SA2'][i]
        df1966 = df1966.drop(columns = ['SA1', 'SA2'])
    if ',' in df1966['Svs'][i]:
        df1966[['Svs1', 'Svs2']] = df1966['Svs'].str.split(',', expand = True)
        df1966['Svs'][i] = df1966['Svs1'][i] + df1966['Svs2'][i]
        df1966 = df1966.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1967)):
    if ',' in df1967['SA'][i]:
        df1967[['SA1', 'SA2']] = df1967['SA'].str.split(',', expand = True)
        df1967['SA'][i] = df1967['SA1'][i] + df1967['SA2'][i]
        df1967 = df1967.drop(columns = ['SA1', 'SA2'])
    if ',' in df1967['Svs'][i]:
        df1967[['Svs1', 'Svs2']] = df1967['Svs'].str.split(',', expand = True)
        df1967['Svs'][i] = df1967['Svs1'][i] + df1967['Svs2'][i]
        df1967 = df1967.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1968)):
    if ',' in df1968['SA'][i]:
        df1968[['SA1', 'SA2']] = df1968['SA'].str.split(',', expand = True)
        df1968['SA'][i] = df1968['SA1'][i] + df1968['SA2'][i]
        df1968 = df1968.drop(columns = ['SA1', 'SA2'])
    if ',' in df1968['Svs'][i]:
        df1968[['Svs1', 'Svs2']] = df1968['Svs'].str.split(',', expand = True)
        df1968['Svs'][i] = df1968['Svs1'][i] + df1968['Svs2'][i]
        df1968 = df1968.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1969)):
    if ',' in df1969['SA'][i]:
        df1969[['SA1', 'SA2']] = df1969['SA'].str.split(',', expand = True)
        df1969['SA'][i] = df1969['SA1'][i] + df1969['SA2'][i]
        df1969 = df1969.drop(columns = ['SA1', 'SA2'])
    if ',' in df1969['Svs'][i]:
        df1969[['Svs1', 'Svs2']] = df1969['Svs'].str.split(',', expand = True)
        df1969['Svs'][i] = df1969['Svs1'][i] + df1969['Svs2'][i]
        df1969 = df1969.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1970)):
    if ',' in df1970['SA'][i]:
        df1970[['SA1', 'SA2']] = df1970['SA'].str.split(',', expand = True)
        df1970['SA'][i] = df1970['SA1'][i] + df1970['SA2'][i]
        df1970 = df1970.drop(columns = ['SA1', 'SA2'])
    if ',' in df1970['Svs'][i]:
        df1970[['Svs1', 'Svs2']] = df1970['Svs'].str.split(',', expand = True)
        df1970['Svs'][i] = df1970['Svs1'][i] + df1970['Svs2'][i]
        df1970 = df1970.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1971)):
    if ',' in df1971['SA'][i]:
        df1971[['SA1', 'SA2']] = df1971['SA'].str.split(',', expand = True)
        df1971['SA'][i] = df1971['SA1'][i] + df1971['SA2'][i]
        df1971 = df1971.drop(columns = ['SA1', 'SA2'])
    if ',' in df1971['Svs'][i]:
        df1971[['Svs1', 'Svs2']] = df1971['Svs'].str.split(',', expand = True)
        df1971['Svs'][i] = df1971['Svs1'][i] + df1971['Svs2'][i]
        df1971 = df1971.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1972)):
    if ',' in df1972['SA'][i]:
        df1972[['SA1', 'SA2']] = df1972['SA'].str.split(',', expand = True)
        df1972['SA'][i] = df1972['SA1'][i] + df1972['SA2'][i]
        df1972 = df1972.drop(columns = ['SA1', 'SA2'])
    if ',' in df1972['Svs'][i]:
        df1972[['Svs1', 'Svs2']] = df1972['Svs'].str.split(',', expand = True)
        df1972['Svs'][i] = df1972['Svs1'][i] + df1972['Svs2'][i]
        df1972 = df1972.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1973)):
    if ',' in df1973['SA'][i]:
        df1973[['SA1', 'SA2']] = df1973['SA'].str.split(',', expand = True)
        df1973['SA'][i] = df1973['SA1'][i] + df1973['SA2'][i]
        df1973 = df1973.drop(columns = ['SA1', 'SA2'])
    if ',' in df1973['Svs'][i]:
        df1973[['Svs1', 'Svs2']] = df1973['Svs'].str.split(',', expand = True)
        df1973['Svs'][i] = df1973['Svs1'][i] + df1973['Svs2'][i]
        df1973 = df1973.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1974)):
    if ',' in df1974['SA'][i]:
        df1974[['SA1', 'SA2']] = df1974['SA'].str.split(',', expand = True)
        df1974['SA'][i] = df1974['SA1'][i] + df1974['SA2'][i]
        df1974 = df1974.drop(columns = ['SA1', 'SA2'])
    if ',' in df1974['Svs'][i]:
        df1974[['Svs1', 'Svs2']] = df1974['Svs'].str.split(',', expand = True)
        df1974['Svs'][i] = df1974['Svs1'][i] + df1974['Svs2'][i]
        df1974 = df1974.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1975)):
    if ',' in df1975['SA'][i]:
        df1975[['SA1', 'SA2']] = df1975['SA'].str.split(',', expand = True)
        df1975['SA'][i] = df1975['SA1'][i] + df1975['SA2'][i]
        df1975 = df1975.drop(columns = ['SA1', 'SA2'])
    if ',' in df1975['Svs'][i]:
        df1975[['Svs1', 'Svs2']] = df1975['Svs'].str.split(',', expand = True)
        df1975['Svs'][i] = df1975['Svs1'][i] + df1975['Svs2'][i]
        df1975 = df1975.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1976)):
    if ',' in df1976['SA'][i]:
        df1976[['SA1', 'SA2']] = df1976['SA'].str.split(',', expand = True)
        df1976['SA'][i] = df1976['SA1'][i] + df1976['SA2'][i]
        df1976 = df1976.drop(columns = ['SA1', 'SA2'])
    if ',' in df1976['Svs'][i]:
        df1976[['Svs1', 'Svs2']] = df1976['Svs'].str.split(',', expand = True)
        df1976['Svs'][i] = df1976['Svs1'][i] + df1976['Svs2'][i]
        df1976 = df1976.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1977)):
    if ',' in df1977['SA'][i]:
        df1977[['SA1', 'SA2']] = df1977['SA'].str.split(',', expand = True)
        df1977['SA'][i] = df1977['SA1'][i] + df1977['SA2'][i]
        df1977 = df1977.drop(columns = ['SA1', 'SA2'])
    if ',' in df1977['Svs'][i]:
        df1977[['Svs1', 'Svs2']] = df1977['Svs'].str.split(',', expand = True)
        df1977['Svs'][i] = df1977['Svs1'][i] + df1977['Svs2'][i]
        df1977 = df1977.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1978)):
    if ',' in df1978['SA'][i]:
        df1978[['SA1', 'SA2']] = df1978['SA'].str.split(',', expand = True)
        df1978['SA'][i] = df1978['SA1'][i] + df1978['SA2'][i]
        df1978 = df1978.drop(columns = ['SA1', 'SA2'])
    if ',' in df1978['Svs'][i]:
        df1978[['Svs1', 'Svs2']] = df1978['Svs'].str.split(',', expand = True)
        df1978['Svs'][i] = df1978['Svs1'][i] + df1978['Svs2'][i]
        df1978 = df1978.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1979)):
    if ',' in df1979['SA'][i]:
        df1979[['SA1', 'SA2']] = df1979['SA'].str.split(',', expand = True)
        df1979['SA'][i] = df1979['SA1'][i] + df1979['SA2'][i]
        df1979 = df1979.drop(columns = ['SA1', 'SA2'])
    if ',' in df1979['Svs'][i]:
        df1979[['Svs1', 'Svs2']] = df1979['Svs'].str.split(',', expand = True)
        df1979['Svs'][i] = df1979['Svs1'][i] + df1979['Svs2'][i]
        df1979 = df1979.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1980)):
    if ',' in df1980['SA'][i]:
        df1980[['SA1', 'SA2']] = df1980['SA'].str.split(',', expand = True)
        df1980['SA'][i] = df1980['SA1'][i] + df1980['SA2'][i]
        df1980 = df1980.drop(columns = ['SA1', 'SA2'])
    if ',' in df1980['Svs'][i]:
        df1980[['Svs1', 'Svs2']] = df1980['Svs'].str.split(',', expand = True)
        df1980['Svs'][i] = df1980['Svs1'][i] + df1980['Svs2'][i]
        df1980 = df1980.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1981)):
    if ',' in df1981['SA'][i]:
        df1981[['SA1', 'SA2']] = df1981['SA'].str.split(',', expand = True)
        df1981['SA'][i] = df1981['SA1'][i] + df1981['SA2'][i]
        df1981 = df1981.drop(columns = ['SA1', 'SA2'])
    if ',' in df1981['Svs'][i]:
        df1981[['Svs1', 'Svs2']] = df1981['Svs'].str.split(',', expand = True)
        df1981['Svs'][i] = df1981['Svs1'][i] + df1981['Svs2'][i]
        df1981 = df1981.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1982)):
    if ',' in df1982['SA'][i]:
        df1982[['SA1', 'SA2']] = df1982['SA'].str.split(',', expand = True)
        df1982['SA'][i] = df1982['SA1'][i] + df1982['SA2'][i]
        df1982 = df1982.drop(columns = ['SA1', 'SA2'])
    if ',' in df1982['Svs'][i]:
        df1982[['Svs1', 'Svs2']] = df1982['Svs'].str.split(',', expand = True)
        df1982['Svs'][i] = df1982['Svs1'][i] + df1982['Svs2'][i]
        df1982 = df1982.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1983)):
    if ',' in df1983['SA'][i]:
        df1983[['SA1', 'SA2']] = df1983['SA'].str.split(',', expand = True)
        df1983['SA'][i] = df1983['SA1'][i] + df1983['SA2'][i]
        df1983 = df1983.drop(columns = ['SA1', 'SA2'])
    if ',' in df1983['Svs'][i]:
        df1983[['Svs1', 'Svs2']] = df1983['Svs'].str.split(',', expand = True)
        df1983['Svs'][i] = df1983['Svs1'][i] + df1983['Svs2'][i]
        df1983 = df1983.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1984)):
    if ',' in df1984['SA'][i]:
        df1984[['SA1', 'SA2']] = df1984['SA'].str.split(',', expand = True)
        df1984['SA'][i] = df1984['SA1'][i] + df1984['SA2'][i]
        df1984 = df1984.drop(columns = ['SA1', 'SA2'])
    if ',' in df1984['Svs'][i]:
        df1984[['Svs1', 'Svs2']] = df1984['Svs'].str.split(',', expand = True)
        df1984['Svs'][i] = df1984['Svs1'][i] + df1984['Svs2'][i]
        df1984 = df1984.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1985)):
    if ',' in df1985['SA'][i]:
        df1985[['SA1', 'SA2']] = df1985['SA'].str.split(',', expand = True)
        df1985['SA'][i] = df1985['SA1'][i] + df1985['SA2'][i]
        df1985 = df1985.drop(columns = ['SA1', 'SA2'])
    if ',' in df1985['Svs'][i]:
        df1985[['Svs1', 'Svs2']] = df1985['Svs'].str.split(',', expand = True)
        df1985['Svs'][i] = df1985['Svs1'][i] + df1985['Svs2'][i]
        df1985 = df1985.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1986)):
    if ',' in df1986['SA'][i]:
        df1986[['SA1', 'SA2']] = df1986['SA'].str.split(',', expand = True)
        df1986['SA'][i] = df1986['SA1'][i] + df1986['SA2'][i]
        df1986 = df1986.drop(columns = ['SA1', 'SA2'])
    if ',' in df1986['Svs'][i]:
        df1986[['Svs1', 'Svs2']] = df1986['Svs'].str.split(',', expand = True)
        df1986['Svs'][i] = df1986['Svs1'][i] + df1986['Svs2'][i]
        df1986 = df1986.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1987)):
    if ',' in df1987['SA'][i]:
        df1987[['SA1', 'SA2']] = df1987['SA'].str.split(',', expand = True)
        df1987['SA'][i] = df1987['SA1'][i] + df1987['SA2'][i]
        df1987 = df1987.drop(columns = ['SA1', 'SA2'])
    if ',' in df1987['Svs'][i]:
        df1987[['Svs1', 'Svs2']] = df1987['Svs'].str.split(',', expand = True)
        df1987['Svs'][i] = df1987['Svs1'][i] + df1987['Svs2'][i]
        df1987 = df1987.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1988)):
    if ',' in df1988['SA'][i]:
        df1988[['SA1', 'SA2']] = df1988['SA'].str.split(',', expand = True)
        df1988['SA'][i] = df1988['SA1'][i] + df1988['SA2'][i]
        df1988 = df1988.drop(columns = ['SA1', 'SA2'])
    if ',' in df1988['Svs'][i]:
        df1988[['Svs1', 'Svs2']] = df1988['Svs'].str.split(',', expand = True)
        df1988['Svs'][i] = df1988['Svs1'][i] + df1988['Svs2'][i]
        df1988 = df1988.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1989)):
    if ',' in df1989['SA'][i]:
        df1989[['SA1', 'SA2']] = df1989['SA'].str.split(',', expand = True)
        df1989['SA'][i] = df1989['SA1'][i] + df1989['SA2'][i]
        df1989 = df1989.drop(columns = ['SA1', 'SA2'])
    if ',' in df1989['Svs'][i]:
        df1989[['Svs1', 'Svs2']] = df1989['Svs'].str.split(',', expand = True)
        df1989['Svs'][i] = df1989['Svs1'][i] + df1989['Svs2'][i]
        df1989 = df1989.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1990)):
    if ',' in df1990['SA'][i]:
        df1990[['SA1', 'SA2']] = df1990['SA'].str.split(',', expand = True)
        df1990['SA'][i] = df1990['SA1'][i] + df1990['SA2'][i]
        df1990 = df1990.drop(columns = ['SA1', 'SA2'])
    if ',' in df1990['Svs'][i]:
        df1990[['Svs1', 'Svs2']] = df1990['Svs'].str.split(',', expand = True)
        df1990['Svs'][i] = df1990['Svs1'][i] + df1990['Svs2'][i]
        df1990 = df1990.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1991)):
    if ',' in df1991['SA'][i]:
        df1991[['SA1', 'SA2']] = df1991['SA'].str.split(',', expand = True)
        df1991['SA'][i] = df1991['SA1'][i] + df1991['SA2'][i]
        df1991 = df1991.drop(columns = ['SA1', 'SA2'])
    if ',' in df1991['Svs'][i]:
        df1991[['Svs1', 'Svs2']] = df1991['Svs'].str.split(',', expand = True)
        df1991['Svs'][i] = df1991['Svs1'][i] + df1991['Svs2'][i]
        df1991 = df1991.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1992)):
    if ',' in df1992['SA'][i]:
        df1992[['SA1', 'SA2']] = df1992['SA'].str.split(',', expand = True)
        df1992['SA'][i] = df1992['SA1'][i] + df1992['SA2'][i]
        df1992 = df1992.drop(columns = ['SA1', 'SA2'])
    if ',' in df1992['Svs'][i]:
        df1992[['Svs1', 'Svs2']] = df1992['Svs'].str.split(',', expand = True)
        df1992['Svs'][i] = df1992['Svs1'][i] + df1992['Svs2'][i]
        df1992 = df1992.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1993)):
    if ',' in df1993['SA'][i]:
        df1993[['SA1', 'SA2']] = df1993['SA'].str.split(',', expand = True)
        df1993['SA'][i] = df1993['SA1'][i] + df1993['SA2'][i]
        df1993 = df1993.drop(columns = ['SA1', 'SA2'])
    if ',' in df1993['Svs'][i]:
        df1993[['Svs1', 'Svs2']] = df1993['Svs'].str.split(',', expand = True)
        df1993['Svs'][i] = df1993['Svs1'][i] + df1993['Svs2'][i]
        df1993 = df1993.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1994)):
    if ',' in df1994['SA'][i]:
        df1994[['SA1', 'SA2']] = df1994['SA'].str.split(',', expand = True)
        df1994['SA'][i] = df1994['SA1'][i] + df1994['SA2'][i]
        df1994 = df1994.drop(columns = ['SA1', 'SA2'])
    if ',' in df1994['Svs'][i]:
        df1994[['Svs1', 'Svs2']] = df1994['Svs'].str.split(',', expand = True)
        df1994['Svs'][i] = df1994['Svs1'][i] + df1994['Svs2'][i]
        df1994 = df1994.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1995)):
    if ',' in df1995['SA'][i]:
        df1995[['SA1', 'SA2']] = df1995['SA'].str.split(',', expand = True)
        df1995['SA'][i] = df1995['SA1'][i] + df1995['SA2'][i]
        df1995 = df1995.drop(columns = ['SA1', 'SA2'])
    if ',' in df1995['Svs'][i]:
        df1995[['Svs1', 'Svs2']] = df1995['Svs'].str.split(',', expand = True)
        df1995['Svs'][i] = df1995['Svs1'][i] + df1995['Svs2'][i]
        df1995 = df1995.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1996)):
    if ',' in df1996['SA'][i]:
        df1996[['SA1', 'SA2']] = df1996['SA'].str.split(',', expand = True)
        df1996['SA'][i] = df1996['SA1'][i] + df1996['SA2'][i]
        df1996 = df1996.drop(columns = ['SA1', 'SA2'])
    if ',' in df1996['Svs'][i]:
        df1996[['Svs1', 'Svs2']] = df1996['Svs'].str.split(',', expand = True)
        df1996['Svs'][i] = df1996['Svs1'][i] + df1996['Svs2'][i]
        df1996 = df1996.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1997)):
    if ',' in df1997['SA'][i]:
        df1997[['SA1', 'SA2']] = df1997['SA'].str.split(',', expand = True)
        df1997['SA'][i] = df1997['SA1'][i] + df1997['SA2'][i]
        df1997 = df1997.drop(columns = ['SA1', 'SA2'])
    if ',' in df1997['Svs'][i]:
        df1997[['Svs1', 'Svs2']] = df1997['Svs'].str.split(',', expand = True)
        df1997['Svs'][i] = df1997['Svs1'][i] + df1997['Svs2'][i]
        df1997 = df1997.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1998)):
    if ',' in df1998['SA'][i]:
        df1998[['SA1', 'SA2']] = df1998['SA'].str.split(',', expand = True)
        df1998['SA'][i] = df1998['SA1'][i] + df1998['SA2'][i]
        df1998 = df1998.drop(columns = ['SA1', 'SA2'])
    if ',' in df1998['Svs'][i]:
        df1998[['Svs1', 'Svs2']] = df1998['Svs'].str.split(',', expand = True)
        df1998['Svs'][i] = df1998['Svs1'][i] + df1998['Svs2'][i]
        df1998 = df1998.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df1999)):
    if ',' in df1999['SA'][i]:
        df1999[['SA1', 'SA2']] = df1999['SA'].str.split(',', expand = True)
        df1999['SA'][i] = df1999['SA1'][i] + df1999['SA2'][i]
        df1999 = df1999.drop(columns = ['SA1', 'SA2'])
    if ',' in df1999['Svs'][i]:
        df1999[['Svs1', 'Svs2']] = df1999['Svs'].str.split(',', expand = True)
        df1999['Svs'][i] = df1999['Svs1'][i] + df1999['Svs2'][i]
        df1999 = df1999.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2000)):
    if ',' in df2000['SA'][i]:
        df2000[['SA1', 'SA2']] = df2000['SA'].str.split(',', expand = True)
        df2000['SA'][i] = df2000['SA1'][i] + df2000['SA2'][i]
        df2000 = df2000.drop(columns = ['SA1', 'SA2'])
    if ',' in df2000['Svs'][i]:
        df2000[['Svs1', 'Svs2']] = df2000['Svs'].str.split(',', expand = True)
        df2000['Svs'][i] = df2000['Svs1'][i] + df2000['Svs2'][i]
        df2000 = df2000.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2001)):
    if ',' in df2001['SA'][i]:
        df2001[['SA1', 'SA2']] = df2001['SA'].str.split(',', expand = True)
        df2001['SA'][i] = df2001['SA1'][i] + df2001['SA2'][i]
        df2001 = df2001.drop(columns = ['SA1', 'SA2'])
    if ',' in df2001['Svs'][i]:
        df2001[['Svs1', 'Svs2']] = df2001['Svs'].str.split(',', expand = True)
        df2001['Svs'][i] = df2001['Svs1'][i] + df2001['Svs2'][i]
        df2001 = df2001.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2002)):
    if ',' in df2002['SA'][i]:
        df2002[['SA1', 'SA2']] = df2002['SA'].str.split(',', expand = True)
        df2002['SA'][i] = df2002['SA1'][i] + df2002['SA2'][i]
        df2002 = df2002.drop(columns = ['SA1', 'SA2'])
    if ',' in df2002['Svs'][i]:
        df2002[['Svs1', 'Svs2']] = df2002['Svs'].str.split(',', expand = True)
        df2002['Svs'][i] = df2002['Svs1'][i] + df2002['Svs2'][i]
        df2002 = df2002.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2003)):
    if ',' in df2003['SA'][i]:
        df2003[['SA1', 'SA2']] = df2003['SA'].str.split(',', expand = True)
        df2003['SA'][i] = df2003['SA1'][i] + df2003['SA2'][i]
        df2003 = df2003.drop(columns = ['SA1', 'SA2'])
    if ',' in df2003['Svs'][i]:
        df2003[['Svs1', 'Svs2']] = df2003['Svs'].str.split(',', expand = True)
        df2003['Svs'][i] = df2003['Svs1'][i] + df2003['Svs2'][i]
        df2003 = df2003.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2004)):
    if ',' in df2004['SA'][i]:
        df2004[['SA1', 'SA2']] = df2004['SA'].str.split(',', expand = True)
        df2004['SA'][i] = df2004['SA1'][i] + df2004['SA2'][i]
        df2004 = df2004.drop(columns = ['SA1', 'SA2'])
    if ',' in df2004['Svs'][i]:
        df2004[['Svs1', 'Svs2']] = df2004['Svs'].str.split(',', expand = True)
        df2004['Svs'][i] = df2004['Svs1'][i] + df2004['Svs2'][i]
        df2004 = df2004.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2006)):
    if ',' in df2006['SA'][i]:
        df2006[['SA1', 'SA2']] = df2006['SA'].str.split(',', expand = True)
        df2006['SA'][i] = df2006['SA1'][i] + df2006['SA2'][i]
        df2006 = df2006.drop(columns = ['SA1', 'SA2'])
    if ',' in df2006['Svs'][i]:
        df2006[['Svs1', 'Svs2']] = df2006['Svs'].str.split(',', expand = True)
        df2006['Svs'][i] = df2006['Svs1'][i] + df2006['Svs2'][i]
        df2006 = df2006.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2007)):
    if ',' in df2007['SA'][i]:
        df2007[['SA1', 'SA2']] = df2007['SA'].str.split(',', expand = True)
        df2007['SA'][i] = df2007['SA1'][i] + df2007['SA2'][i]
        df2007 = df2007.drop(columns = ['SA1', 'SA2'])
    if ',' in df2007['Svs'][i]:
        df2007[['Svs1', 'Svs2']] = df2007['Svs'].str.split(',', expand = True)
        df2007['Svs'][i] = df2007['Svs1'][i] + df2007['Svs2'][i]
        df2007 = df2007.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2008)):
    if ',' in df2008['SA'][i]:
        df2008[['SA1', 'SA2']] = df2008['SA'].str.split(',', expand = True)
        df2008['SA'][i] = df2008['SA1'][i] + df2008['SA2'][i]
        df2008 = df2008.drop(columns = ['SA1', 'SA2'])
    if ',' in df2008['Svs'][i]:
        df2008[['Svs1', 'Svs2']] = df2008['Svs'].str.split(',', expand = True)
        df2008['Svs'][i] = df2008['Svs1'][i] + df2008['Svs2'][i]
        df2008 = df2008.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2009)):
    if ',' in df2009['SA'][i]:
        df2009[['SA1', 'SA2']] = df2009['SA'].str.split(',', expand = True)
        df2009['SA'][i] = df2009['SA1'][i] + df2009['SA2'][i]
        df2009 = df2009.drop(columns = ['SA1', 'SA2'])
    if ',' in df2009['Svs'][i]:
        df2009[['Svs1', 'Svs2']] = df2009['Svs'].str.split(',', expand = True)
        df2009['Svs'][i] = df2009['Svs1'][i] + df2009['Svs2'][i]
        df2009 = df2009.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2010)):
    if ',' in df2010['SA'][i]:
        df2010[['SA1', 'SA2']] = df2010['SA'].str.split(',', expand = True)
        df2010['SA'][i] = df2010['SA1'][i] + df2010['SA2'][i]
        df2010 = df2010.drop(columns = ['SA1', 'SA2'])
    if ',' in df2010['Svs'][i]:
        df2010[['Svs1', 'Svs2']] = df2010['Svs'].str.split(',', expand = True)
        df2010['Svs'][i] = df2010['Svs1'][i] + df2010['Svs2'][i]
        df2010 = df2010.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2011)):
    if ',' in df2011['SA'][i]:
        df2011[['SA1', 'SA2']] = df2011['SA'].str.split(',', expand = True)
        df2011['SA'][i] = df2011['SA1'][i] + df2011['SA2'][i]
        df2011 = df2011.drop(columns = ['SA1', 'SA2'])
    if ',' in df2011['Svs'][i]:
        df2011[['Svs1', 'Svs2']] = df2011['Svs'].str.split(',', expand = True)
        df2011['Svs'][i] = df2011['Svs1'][i] + df2011['Svs2'][i]
        df2011 = df2011.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2012)):
    if ',' in df2012['SA'][i]:
        df2012[['SA1', 'SA2']] = df2012['SA'].str.split(',', expand = True)
        df2012['SA'][i] = df2012['SA1'][i] + df2012['SA2'][i]
        df2012 = df2012.drop(columns = ['SA1', 'SA2'])
    if ',' in df2012['Svs'][i]:
        df2012[['Svs1', 'Svs2']] = df2012['Svs'].str.split(',', expand = True)
        df2012['Svs'][i] = df2012['Svs1'][i] + df2012['Svs2'][i]
        df2012 = df2012.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2013)):
    if ',' in df2013['SA'][i]:
        df2013[['SA1', 'SA2']] = df2013['SA'].str.split(',', expand = True)
        df2013['SA'][i] = df2013['SA1'][i] + df2013['SA2'][i]
        df2013 = df2013.drop(columns = ['SA1', 'SA2'])
    if ',' in df2013['Svs'][i]:
        df2013[['Svs1', 'Svs2']] = df2013['Svs'].str.split(',', expand = True)
        df2013['Svs'][i] = df2013['Svs1'][i] + df2013['Svs2'][i]
        df2013 = df2013.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2014)):
    if ',' in df2014['SA'][i]:
        df2014[['SA1', 'SA2']] = df2014['SA'].str.split(',', expand = True)
        df2014['SA'][i] = df2014['SA1'][i] + df2014['SA2'][i]
        df2014 = df2014.drop(columns = ['SA1', 'SA2'])
    if ',' in df2014['Svs'][i]:
        df2014[['Svs1', 'Svs2']] = df2014['Svs'].str.split(',', expand = True)
        df2014['Svs'][i] = df2014['Svs1'][i] + df2014['Svs2'][i]
        df2014 = df2014.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2015)):
    if ',' in df2015['SA'][i]:
        df2015[['SA1', 'SA2']] = df2015['SA'].str.split(',', expand = True)
        df2015['SA'][i] = df2015['SA1'][i] + df2015['SA2'][i]
        df2015 = df2015.drop(columns = ['SA1', 'SA2'])
    if ',' in df2015['Svs'][i]:
        df2015[['Svs1', 'Svs2']] = df2015['Svs'].str.split(',', expand = True)
        df2015['Svs'][i] = df2015['Svs1'][i] + df2015['Svs2'][i]
        df2015 = df2015.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2016)):
    if ',' in df2016['SA'][i]:
        df2016[['SA1', 'SA2']] = df2016['SA'].str.split(',', expand = True)
        df2016['SA'][i] = df2016['SA1'][i] + df2016['SA2'][i]
        df2016 = df2016.drop(columns = ['SA1', 'SA2'])
    if ',' in df2016['Svs'][i]:
        df2016[['Svs1', 'Svs2']] = df2016['Svs'].str.split(',', expand = True)
        df2016['Svs'][i] = df2016['Svs1'][i] + df2016['Svs2'][i]
        df2016 = df2016.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2017)):
    if ',' in df2017['SA'][i]:
        df2017[['SA1', 'SA2']] = df2017['SA'].str.split(',', expand = True)
        df2017['SA'][i] = df2017['SA1'][i] + df2017['SA2'][i]
        df2017 = df2017.drop(columns = ['SA1', 'SA2'])
    if ',' in df2017['Svs'][i]:
        df2017[['Svs1', 'Svs2']] = df2017['Svs'].str.split(',', expand = True)
        df2017['Svs'][i] = df2017['Svs1'][i] + df2017['Svs2'][i]
        df2017 = df2017.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2018)):
    if ',' in df2018['SA'][i]:
        df2018[['SA1', 'SA2']] = df2018['SA'].str.split(',', expand = True)
        df2018['SA'][i] = df2018['SA1'][i] + df2018['SA2'][i]
        df2018 = df2018.drop(columns = ['SA1', 'SA2'])
    if ',' in df2018['Svs'][i]:
        df2018[['Svs1', 'Svs2']] = df2018['Svs'].str.split(',', expand = True)
        df2018['Svs'][i] = df2018['Svs1'][i] + df2018['Svs2'][i]
        df2018 = df2018.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2019)):
    if ',' in df2019['SA'][i]:
        df2019[['SA1', 'SA2']] = df2019['SA'].str.split(',', expand = True)
        df2019['SA'][i] = df2019['SA1'][i] + df2019['SA2'][i]
        df2019 = df2019.drop(columns = ['SA1', 'SA2'])
    if ',' in df2019['Svs'][i]:
        df2019[['Svs1', 'Svs2']] = df2019['Svs'].str.split(',', expand = True)
        df2019['Svs'][i] = df2019['Svs1'][i] + df2019['Svs2'][i]
        df2019 = df2019.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2020)):
    if ',' in df2020['SA'][i]:
        df2020[['SA1', 'SA2']] = df2020['SA'].str.split(',', expand = True)
        df2020['SA'][i] = df2020['SA1'][i] + df2020['SA2'][i]
        df2020 = df2020.drop(columns = ['SA1', 'SA2'])
    if ',' in df2020['Svs'][i]:
        df2020[['Svs1', 'Svs2']] = df2020['Svs'].str.split(',', expand = True)
        df2020['Svs'][i] = df2020['Svs1'][i] + df2020['Svs2'][i]
        df2020 = df2020.drop(columns = ['Svs1', 'Svs2'])
        
for i in range(0, len(df2021)):
    if ',' in df2021['SA'][i]:
        df2021[['SA1', 'SA2']] = df2021['SA'].str.split(',', expand = True)
        df2021['SA'][i] = df2021['SA1'][i] + df2021['SA2'][i]
        df2021 = df2021.drop(columns = ['SA1', 'SA2'])
    if ',' in df2021['Svs'][i]:
        df2021[['Svs1', 'Svs2']] = df2021['Svs'].str.split(',', expand = True)
        df2021['Svs'][i] = df2021['Svs1'][i] + df2021['Svs2'][i]
        df2021 = df2021.drop(columns = ['Svs1', 'Svs2'])
# Out:
# <ipython-input-7-a5f9fff11203>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1956['SA'][i] = df1956['SA1'][i] + df1956['SA2'][i]
# <ipython-input-7-a5f9fff11203>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1956['Svs'][i] = df1956['Svs1'][i] + df1956['Svs2'][i]
# <ipython-input-7-a5f9fff11203>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1957['SA'][i] = df1957['SA1'][i] + df1957['SA2'][i]
# ...

# %% [markdown]
# # Calculate GAA By Year

# %%
df_list = [df1918, df1919, df1920, df1921, df1922, df1923, df1924, df1925, df1926, df1927, df1928, df1929, df1930, df1931, df1932, df1933, df1934, df1935, df1936, df1937, df1938, df1939, df1940, df1941, df1942, df1943, df1944, df1945, df1946, df1947, df1948, df1949, df1950, df1951, df1952, df1953, df1954, df1955, df1956, df1957, df1958, df1959, df1960, df1961, df1962, df1963, df1964, df1965, df1966, df1967, df1968, df1969, df1970, df1971, df1972, df1973, df1974, df1975, df1976, df1977, df1978, df1979, df1980, df1981, df1982, df1983, df1984, df1985, df1986, df1987, df1988, df1989, df1990, df1991, df1992, df1993, df1994, df1995, df1996, df1997, df1998, df1999, df2000, df2001, df2002, df2003, df2004, df2006, df2007, df2008, df2009, df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021]

# %%
GAA = [0]*(2021-1918)

for i in range(0, len(df_list)):
    GAA[i] = df_list[i]['GA'].sum()/df_list[i]['Actual GP'].sum()

# %%
GAA_df = pd.DataFrame(data = GAA, columns = ['GAA'])
GAA_df['Year'] = ''
for i in range(1918, 2005):
    GAA_df['Year'][i-1918] = i
    
for i in range(2006, 2022):
    GAA_df['Year'][i-1919] = i
# Out:
# <ipython-input-28-efb6dd5ea163>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GAA_df['Year'][i-1918] = i
# <ipython-input-28-efb6dd5ea163>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GAA_df['Year'][i-1919] = i

# %%
GAA_df
# Out:
#           GAA  Year
# 0    4.975149  1918
# 1    4.041075  1919
# 2    4.766153  1920
# 3    4.186886  1921
# 4    3.867466  1922
# ..        ...   ...
# 98   2.593735  2017
# 99   2.781029  2018
# 100  2.814644  2019
# 101  2.818010  2020
# 102  2.740002  2021
#
# [103 rows x 2 columns]

# %% [markdown]
# # Plot GAA Over Time

# %%
plt.plot(GAA_df['Year'], GAA_df['GAA'], c = 'black')
plt.ylabel('Goals Against Average')
plt.xlabel('Year')
plt.title('NHL Goals Against Average Over Time (1918-2021)')
plt.show()

# %% [markdown]
# # Calculate Sv% Over Time

# %%
Sv_Per = [0]*(2021-1956)
shots_df_list = df_list[38:]
for df in shots_df_list:
    df['Svs'] = pd.to_numeric(df['Svs'])
    df['SA'] = pd.to_numeric(df['SA'])

for i in range(0, len(shots_df_list)):
    Sv_Per[i] = shots_df_list[i]['Svs'].sum()/shots_df_list[i]['SA'].sum()

# %%
Sv_Per_df = pd.DataFrame(data = Sv_Per, columns = ['Sv%'])
Sv_Per_df['Year'] = ''
for i in range(1956, 2005):
    Sv_Per_df['Year'][i-1956] = i
    
for i in range(2006, 2022):
    Sv_Per_df['Year'][i-1957] = i
# Out:
# <ipython-input-47-ad2041c684c1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sv_Per_df['Year'][i-1956] = i
# <ipython-input-47-ad2041c684c1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sv_Per_df['Year'][i-1957] = i

# %% [markdown]
# # Plot Sv% Over Time

# %%
plt.plot(Sv_Per_df['Year'], Sv_Per_df['Sv%'], c = 'black')
plt.ylabel('Save Percentage')
plt.xlabel('Year')
plt.title('NHL Save Percentage Over Time (1956-2021)')
plt.show()
